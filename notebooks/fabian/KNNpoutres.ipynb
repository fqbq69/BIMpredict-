# %%
import os
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.multioutput import MultiOutputClassifier

# %%
base_dir = "/Users/fabiancordenod/code/fqbq69/BIMpredict-/raw_data"

dfs = []
for i in range(1, 43):
    poutres_path = os.path.join(base_dir, f"maquette{i}", f"poutres{i}.csv")
    if os.path.exists(poutres_path):
        # Cherche la ligne d'en-tête réelle
        with open(poutres_path, encoding="utf-8") as f:
            for idx, line in enumerate(f):
                if line.startswith("Id;"):
                    header_row = idx
                    break
        try:
            df = pd.read_csv(poutres_path, sep=';', header=header_row)
            dfs.append(df)
            print(f"Chargé : {poutres_path} ({df.shape[0]} lignes, {df.shape[1]} colonnes)")
            print(df.head())
        except Exception as e:
            print(f"Erreur de parsing : {poutres_path} -> {e}")
    else:
        print(f"Fichier non trouvé : {poutres_path}")

if dfs:
    poutres_concat = pd.concat(dfs, ignore_index=True)
    print(f"Total concaténé : {poutres_concat.shape[0]} lignes, {poutres_concat.shape[1]} colonnes")
else:
    poutres_concat = pd.DataFrame()
    print("Aucun fichier murs.csv trouvé.")

poutres_concat.head()
# Out:
# Chargé : /Users/fabiancordenod/code/fqbq69/BIMpredict-/raw_data/maquette1/poutres1.csv (778 lignes, 136 colonnes)
#        Id 011EC_Lot 012EC_Ouvrage 013EC_Localisation 014EC_Mode Constructif  \
# 0  822465        GO        POUTRE          INTERIEUR         PREFA CHANTIER
# 1  822610        GO        POUTRE          INTERIEUR         PREFA CHANTIER
# 2  823043        GO   BANDE NOYEE            COURANT         COULE EN PLACE
# 3  823110        GO   BANDE NOYEE            COURANT         COULE EN PLACE
# 4  823289        GO   BANDE NOYEE            COURANT         COULE EN PLACE
#
#        Nom                  AI                 AS Hauteur totale  \
# 0  30x60ht  -0,200000000000001  0,200000000000001            0,6
# 1  25x50ht  -0,150000000000001  0,150000000000001            0,5
# 2  30x20ht                -0,1                0,1            0,2
# 3  30x20ht                -0,1                0,1            0,2
# 4  30x20ht                -0,1                0,1            0,2
#
#              Hauteur  ...  Forme de coupe  Titre OmniClass  Numéro OmniClass  \
# 0  0,400000000000002  ...               0              NaN               NaN
# 1  0,300000000000002  ...               0              NaN               NaN
# 2                0,2  ...               0              NaN               NaN
# 3                0,2  ...               0              NaN               NaN
# 4                0,2  ...               0              NaN               NaN
#
#    Description de l'assemblage Code d'assemblage  Marque de type  \
# 0                          NaN               NaN             NaN
# 1                          NaN               NaN             NaN
# 2                          NaN               NaN             NaN
# 3                          NaN               NaN             NaN
# 4                          NaN               NaN             NaN
#
#    Protection contre l'incendie Coût    h     b
# 0                           NaN    0  0,6   0,3
# 1                           NaN    0  0,5  0,25
# 2                           NaN    0  0,2   0,3
# 3                           NaN    0  0,2   0,3
# 4                           NaN    0  0,2   0,3
#
# [5 rows x 136 columns]
# Chargé : /Users/fabiancordenod/code/fqbq69/BIMpredict-/raw_data/maquette2/poutres2.csv (152 lignes, 136 colonnes)
#        Id 011EC_Lot 012EC_Ouvrage 013EC_Localisation 014EC_Mode Constructif  \
# 0  570797        GO   BANDE NOYEE            COURANT         COULE EN PLACE
# 1  570799        GO   BANDE NOYEE            COURANT         COULE EN PLACE
# 2  570801        GO   BANDE NOYEE            COURANT         COULE EN PLACE
# 3  570803        GO   BANDE NOYEE            COURANT         COULE EN PLACE
# 4  570805        GO   BANDE NOYEE            COURANT         COULE EN PLACE
#
#   Nom                 AI                 AS Hauteur totale Hauteur  ...  \
# 0  BN  0,020000000000003  0,220000000000003            0,2     0,2  ...
# 1  BN  0,020000000000003  0,220000000000003            0,2     0,2  ...
# 2  BN  0,020000000000003  0,220000000000003            0,2     0,2  ...
# 3  BN  0,020000000000003  0,220000000000003            0,2     0,2  ...
# 4  BN  0,020000000000003  0,220000000000003            0,2     0,2  ...
#
#    Titre OmniClass   Numéro OmniClass  Description de l'assemblage  \
# 0            Beams  23.25.30.11.14.14                          NaN
# 1            Beams  23.25.30.11.14.14                          NaN
# 2            Beams  23.25.30.11.14.14                          NaN
# 3            Beams  23.25.30.11.14.14                          NaN
# 4            Beams  23.25.30.11.14.14                          NaN
#
#    Code d'assemblage Marque de type  Protection contre l'incendie  Coût  \
# 0                NaN            NaN                           NaN     0
# 1                NaN            NaN                           NaN     0
# 2                NaN            NaN                           NaN     0
# 3                NaN            NaN                           NaN     0
# 4                NaN            NaN                           NaN     0
#
#   ECH_hauteur  ECH_largeur Type d'attachement de fin
# 0         0,2          0,4                       NaN
# 1         0,2          0,4                       NaN
# 2         0,2          0,4                       NaN
# 3         0,2          0,4                       4.0
# 4         0,2          0,4                       NaN
#
# [5 rows x 136 columns]
# Chargé : /Users/fabiancordenod/code/fqbq69/BIMpredict-/raw_data/maquette3/poutres3.csv (287 lignes, 134 colonnes)
#        Id 011EC_Lot 012EC_Ouvrage 013EC_Localisation 014EC_Mode Constructif  \
# 0  280537        GO        POUTRE          EXTERIEUR            PREFA USINE
# 1  280887        GO        POUTRE          EXTERIEUR            PREFA USINE
# 2  281214        GO        POUTRE          EXTERIEUR            PREFA USINE
# 3  281403        GO        POUTRE          EXTERIEUR            PREFA USINE
# 4  281569        GO        POUTRE          EXTERIEUR            PREFA USINE
#
#          Nom                  AI                 AS     Hauteur totale  \
# 0  400x680ht  -0,239999999999997  0,239999999999997  0,730000000000007
# 1  200x680ht  -0,214999999999986  0,214999999999986  0,679999999999984
# 2  200x730ht  -0,239999999999997  0,239999999999997  0,730000000000007
# 3  200x680ht  -0,214999999999986  0,214999999999986  0,679999999999984
# 4  200x680ht  -0,214999999999986  0,214999999999986  0,679999999999984
#
#              Hauteur  ...   Numéro OmniClass  Description de l'assemblage  \
# 0  0,479999999999995  ...  23.25.30.11.14.14                          NaN
# 1  0,429999999999972  ...  23.25.30.11.14.14                          NaN
# 2  0,479999999999995  ...  23.25.30.11.14.14                          NaN
# 3  0,429999999999972  ...  23.25.30.11.14.14                          NaN
# 4  0,429999999999972  ...  23.25.30.11.14.14                          NaN
#
#    Code d'assemblage  Marque de type Protection contre l'incendie  Coût  \
# 0                NaN             NaN                          NaN     0
# 1                NaN             NaN                          NaN     0
# 2                NaN             NaN                          NaN     0
# 3                NaN             NaN                          NaN     0
# 4                NaN             NaN                          NaN     0
#
#    ECH_hauteur ECH_largeur  Orientation  Plan de construction
# 0         0,73         0,4          NaN                   NaN
# 1         0,68         0,2          NaN                   NaN
# 2         0,73         0,2          NaN                   NaN
# 3         0,68         0,2          NaN                   NaN
# 4         0,68         0,2          NaN                   NaN
#
# [5 rows x 134 columns]
# Chargé : /Users/fabiancordenod/code/fqbq69/BIMpredict-/raw_data/maquette4/poutres4.csv (246 lignes, 100 colonnes)
#         Id 011EC_Lot 012EC_Ouvrage 013EC_Localisation 014EC_Mode Constructif  \
# 0  1632051       NaN           NaN                NaN                    NaN
# 1  1666165       NaN           NaN                NaN                    NaN
# 2  1702917       NaN           NaN                NaN                    NaN
# 3  1788246        GO        POUTRE          INTERIEUR         PREFA CHANTIER
# 4  1788248        GO        POUTRE          EXTERIEUR         PREFA CHANTIER
#
#            Nom     AI     AS                   Hauteur totale  \
# 0  Po(40x60ht)  -4,32  -4,32  0,00000000000000162430069394759
# 1  Po(40x60ht)  -4,32  -4,32  0,00000000000000162430069394759
# 2  Po(40x60ht)  -4,32  -4,32  0,00000000000000162430069394759
# 3  Po(20x60ht)   -0,3    0,3                              0,6
# 4  Po(20x60ht)   -0,3    0,3                              0,6
#
#                            Hauteur  ...  Marque de type  \
# 0  0,00000000000000177635683940025  ...             NaN
# 1  0,00000000000000177635683940025  ...             NaN
# 2  0,00000000000000177635683940025  ...             NaN
# 3                              0,6  ...             NaN
# 4                              0,6  ...             NaN
#
#    Protection contre l'incendie  Coût    h    b  Type Ossature  \
# 0                           NaN     0  0,6  0,4             Po
# 1                           NaN     0  0,6  0,4             Po
# 2                           NaN     0  0,6  0,4             Po
# 3                           NaN     0  0,6  0,2             Po
# 4                           NaN     0  0,6  0,2             Po
#
#    Type d'attachement de fin  Type d'attachement de début  LG_DECAISSE  \
# 0                        NaN                          NaN          NaN
# 1                        NaN                          NaN          NaN
# 2                        NaN                          NaN          NaN
# 3                        NaN                          NaN          NaN
# 4                        NaN                          NaN          NaN
#
#   ht-decaisse
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
# [5 rows x 100 columns]
# Chargé : /Users/fabiancordenod/code/fqbq69/BIMpredict-/raw_data/maquette5/poutres5.csv (96 lignes, 89 colonnes)
#         Id 011EC_Lot 012EC_Ouvrage 013EC_Localisation 014EC_Mode Constructif  \
# 0  1771497        GO      LONGRINE          INTERIEUR                 COFFRE
# 1  1771645        GO      LONGRINE          INTERIEUR                 COFFRE
# 2  1771693        GO      LONGRINE          INTERIEUR                 COFFRE
# 3  1771737        GO      LONGRINE          INTERIEUR                 COFFRE
# 4  1771799        GO      LONGRINE          INTERIEUR                 COFFRE
#
#                    Nom                  AI                 AS  \
# 0  ECRL_Poutre_25x40ht  -0,199999999999998  0,199999999999998
# 1  ECRL_Poutre_25x40ht  -0,199999999999998  0,199999999999998
# 2  ECRL_Poutre_25x40ht  -0,199999999999998  0,199999999999998
# 3  ECRL_Poutre_25x40ht  -0,199999999999998  0,199999999999998
# 4  ECRL_Poutre_25x40ht  -0,199999999999998  0,199999999999998
#
#       Hauteur totale            Hauteur  ...  Forme de coupe  Titre OmniClass  \
# 0  0,399999999999996  0,399999999999996  ...               0            Beams
# 1  0,399999999999996  0,399999999999996  ...               0            Beams
# 2  0,399999999999996  0,399999999999996  ...               0            Beams
# 3  0,399999999999996  0,399999999999996  ...               0            Beams
# 4  0,399999999999996  0,399999999999996  ...               0            Beams
#
#     Numéro OmniClass  Description de l'assemblage Code d'assemblage  \
# 0  23.25.30.11.14.14                          NaN               NaN
# 1  23.25.30.11.14.14                          NaN               NaN
# 2  23.25.30.11.14.14                          NaN               NaN
# 3  23.25.30.11.14.14                          NaN               NaN
# 4  23.25.30.11.14.14                          NaN               NaN
#
#    Marque de type  Protection contre l'incendie  Coût    h     b
# 0             NaN                           NaN     0  0,4  0,25
# 1             NaN                           NaN     0  0,4  0,25
# 2             NaN                           NaN     0  0,4  0,25
# 3             NaN                           NaN     0  0,4  0,25
# 4             NaN                           NaN     0  0,4  0,25
#
# [5 rows x 89 columns]
# Chargé : /Users/fabiancordenod/code/fqbq69/BIMpredict-/raw_data/maquette6/poutres6.csv (287 lignes, 91 colonnes)
#        Id 011EC_Lot 012EC_Ouvrage 013EC_Localisation 014EC_Mode Constructif  \
# 0  280537        GO        POUTRE          EXTERIEUR            PREFA USINE
# 1  280887        GO        POUTRE          EXTERIEUR            PREFA USINE
# 2  281214        GO        POUTRE          EXTERIEUR            PREFA USINE
# 3  281403        GO        POUTRE          EXTERIEUR            PREFA USINE
# 4  281569        GO        POUTRE          EXTERIEUR            PREFA USINE
#
#          Nom                  AI                 AS     Hauteur totale  \
# 0  400x680ht  -0,239999999999997  0,239999999999997  0,730000000000007
# 1  200x680ht  -0,214999999999986  0,214999999999986  0,679999999999984
# 2  200x730ht  -0,239999999999997  0,239999999999997  0,730000000000007
# 3  200x680ht  -0,214999999999986  0,214999999999986  0,679999999999984
# 4  200x680ht  -0,214999999999986  0,214999999999986  0,679999999999984
#
#              Hauteur  ...   Numéro OmniClass  Description de l'assemblage  \
# 0  0,479999999999995  ...  23.25.30.11.14.14                          NaN
# 1  0,429999999999972  ...  23.25.30.11.14.14                          NaN
# 2  0,479999999999995  ...  23.25.30.11.14.14                          NaN
# 3  0,429999999999972  ...  23.25.30.11.14.14                          NaN
# 4  0,429999999999972  ...  23.25.30.11.14.14                          NaN
#
#    Code d'assemblage  Marque de type Protection contre l'incendie  Coût  \
# 0                NaN             NaN                          NaN     0
# 1                NaN             NaN                          NaN     0
# 2                NaN             NaN                          NaN     0
# 3                NaN             NaN                          NaN     0
# 4                NaN             NaN                          NaN     0
#
#    ECH_hauteur  ECH_largeur  Orientation  Plan de construction
# 0         0,73          0,4          NaN                   NaN
# 1         0,68          0,2          NaN                   NaN
# 2         0,73          0,2          NaN                   NaN
# 3         0,68          0,2          NaN                   NaN
# 4         0,68          0,2          NaN                   NaN
#
# [5 rows x 91 columns]
# Chargé : /Users/fabiancordenod/code/fqbq69/BIMpredict-/raw_data/maquette7/poutres7.csv (32 lignes, 105 colonnes)
#        Id 011EC_Lot 012EC_Ouvrage 013EC_Localisation 014EC_Mode Constructif  \
# 0  541813        GO        POUTRE            COURANT         COULE EN PLACE
# 1  541814        GO        POUTRE            COURANT         COULE EN PLACE
# 2  541815        GO        POUTRE            COURANT         COULE EN PLACE
# 3  541816        GO        POUTRE            COURANT         COULE EN PLACE
# 4  541817        GO        POUTRE            COURANT         COULE EN PLACE
#
#        Nom    AI   AS Hauteur totale Hauteur  ...  \
# 0  40x60ht  -0,3  0,3            0,6     0,6  ...
# 1  40x60ht  -0,3  0,3            0,6     0,6  ...
# 2  40x60ht  -0,3  0,3            0,6     0,6  ...
# 3  40x60ht  -0,3  0,3            0,6     0,6  ...
# 4  40x60ht  -0,3  0,3            0,6     0,6  ...
#
#    Description de l'assemblage  Code d'assemblage  Marque de type  \
# 0                          NaN                NaN             NaN
# 1                          NaN                NaN             NaN
# 2                          NaN                NaN             NaN
# 3                          NaN                NaN             NaN
# 4                          NaN                NaN             NaN
#
#    Protection contre l'incendie Coût  ECH_hauteur  ECH_largeur  \
# 0                           NaN    0          0,6          0,4
# 1                           NaN    0          0,6          0,4
# 2                           NaN    0          0,6          0,4
# 3                           NaN    0          0,6          0,4
# 4                           NaN    0          0,6          0,4
#
#    Installation-Fabrication  Construction Details  Installation Phase
# 0                       NaN                   NaN                 NaN
# 1                       NaN                   NaN                 NaN
# 2                       NaN                   NaN                 NaN
# 3                       NaN                   NaN                 NaN
# 4                       NaN                   NaN                 NaN
#
# [5 rows x 105 columns]
# Chargé : /Users/fabiancordenod/code/fqbq69/BIMpredict-/raw_data/maquette8/poutres8.csv (68 lignes, 91 colonnes)
#         Id 011EC_Lot 012EC_Ouvrage 013EC_Localisation 014EC_Mode Constructif  \
# 0  2949713        GO        POUTRE          INTERIEUR         PREFA CHANTIER
# 1  2949721        GO        POUTRE          INTERIEUR         PREFA CHANTIER
# 2  2949727        GO        POUTRE          INTERIEUR         PREFA CHANTIER
# 3  2949731        GO        POUTRE          INTERIEUR         PREFA CHANTIER
# 4  2949733        GO        POUTRE          INTERIEUR         PREFA CHANTIER
#
#        Nom                   AI                  AS Hauteur totale  \
# 0  45x65ht  -0,0750000000000029  0,0750000000000029           0,65
# 1  45x65ht  -0,0750000000000029  0,0750000000000029           0,65
# 2  45x65ht  -0,0750000000000029  0,0750000000000029           0,65
# 3  45x65ht  -0,0750000000000029  0,0750000000000029           0,65
# 4  45x65ht  -0,0750000000000029  0,0750000000000029           0,65
#
#              Hauteur  ...   Numéro OmniClass  Description de l'assemblage  \
# 0  0,150000000000006  ...  23.25.30.11.14.14                          NaN
# 1  0,150000000000006  ...  23.25.30.11.14.14                          NaN
# 2  0,150000000000006  ...  23.25.30.11.14.14                          NaN
# 3  0,150000000000006  ...  23.25.30.11.14.14                          NaN
# 4  0,150000000000006  ...  23.25.30.11.14.14                          NaN
#
#    Code d'assemblage  Marque de type Protection contre l'incendie  Coût     h  \
# 0                NaN             NaN                          NaN     0  0,65
# 1                NaN             NaN                          NaN     0  0,65
# 2                NaN             NaN                          NaN     0  0,65
# 3                NaN             NaN                          NaN     0  0,65
# 4                NaN             NaN                          NaN     0  0,65
#
#       b  Type d'attachement de fin  Type d'attachement de début
# 0  0,45                        NaN                          NaN
# 1  0,45                        NaN                          NaN
# 2  0,45                        4.0                          NaN
# 3  0,45                        NaN                          NaN
# 4  0,45                        4.0                          NaN
#
# [5 rows x 91 columns]
# Chargé : /Users/fabiancordenod/code/fqbq69/BIMpredict-/raw_data/maquette9/poutres9.csv (338 lignes, 110 colonnes)
#         Id 011EC_Lot  012EC_Ouvrage  013EC_Localisation  \
# 0  3021206       NaN            NaN                 NaN
# 1  3021356       NaN            NaN                 NaN
# 2  3021445       NaN            NaN                 NaN
# 3  3021513       NaN            NaN                 NaN
# 4  3021747       NaN            NaN                 NaN
#
#    014EC_Mode Constructif       Nom                  AI                 AS  \
# 0                     NaN   53x65ht  -0,325000000000067  0,325000000000067
# 1                     NaN   53x65ht  -0,325000000000001  0,325000000000001
# 2                     NaN   53x65ht  -0,325000000000001  0,325000000000001
# 3                     NaN  25x105ht              -0,525              0,525
# 4                     NaN  25x105ht              -0,525              0,525
#
#   Hauteur totale            Hauteur  ...  Protection contre l'incendie  Coût  \
# 0           0,65  0,650000000000133  ...                           NaN     0
# 1           0,65  0,650000000000002  ...                           NaN     0
# 2           0,65  0,650000000000002  ...                           NaN     0
# 3           1,05               1,05  ...                           NaN     0
# 4           1,05               1,05  ...                           NaN     0
#
#    ND_Code  str_b str_h  largeur  Type d'attachement de début  \
# 0      PTE   0,53  0,65      NaN                          NaN
# 1      PTE   0,53  0,65      NaN                          NaN
# 2      PTE   0,53  0,65      NaN                          NaN
# 3      NaN   0,25  1,05     0,25                          NaN
# 4      NaN   0,25  1,05     0,25                          4.0
#
#    Réduction du joint de début  Largeur   D1
# 0                          NaN      NaN  NaN
# 1                          NaN      NaN  NaN
# 2                          NaN      NaN  NaN
# 3                          NaN      NaN  NaN
# 4                          NaN      NaN  NaN
#
# [5 rows x 110 columns]
# Chargé : /Users/fabiancordenod/code/fqbq69/BIMpredict-/raw_data/maquette10/poutres10.csv (303 lignes, 100 colonnes)
#         Id 011EC_Lot 012EC_Ouvrage 013EC_Localisation 014EC_Mode Constructif  \
# 0  4389368        GO        POUTRE            COURANT         PREFA CHANTIER
# 1  4389369        GO        POUTRE            COURANT         COULE EN PLACE
# 2  4390633        GO        POUTRE            COURANT         PREFA CHANTIER
# 3  4391390        GO        POUTRE            COURANT         PREFA CHANTIER
# 4  4391391        GO        POUTRE            COURANT         COULE EN PLACE
#
#                    Nom     AI    AS Hauteur totale Hauteur  ...  Coût  A-Code  \
# 0  ECDA_RDC_PO13_30x50  -0,25  0,25           2,75     0,5  ...     0     NaN
# 1                30x50  -0,25  0,25           2,75     0,5  ...     0     NaN
# 2  ECDA_RDC_PO13_30x50  -0,25  0,25           2,75     0,5  ...     0     NaN
# 3   ECDA_R+1_PO9_30x50  -0,25  0,25           2,75     0,5  ...     0     NaN
# 4                30x50  -0,25  0,25           2,75     0,5  ...     0     NaN
#
#     IfcExportAs  IfcDescription    h    b  Orientation  Plan de construction  \
# 0  IfcBeam.BEAM             NaN  0,5  0,3          NaN                   NaN
# 1  IfcBeam.BEAM             NaN  0,5  0,3          NaN                   NaN
# 2  IfcBeam.BEAM             NaN  0,5  0,3          NaN                   NaN
# 3  IfcBeam.BEAM             NaN  0,5  0,3          NaN                   NaN
# 4  IfcBeam.BEAM             NaN  0,5  0,3          NaN                   NaN
#
#    Type d'attachement de début  Type d'attachement de fin
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
#
# [5 rows x 100 columns]
# Chargé : /Users/fabiancordenod/code/fqbq69/BIMpredict-/raw_data/maquette11/poutres11.csv (17 lignes, 100 colonnes)
#        Id  011EC_Lot  012EC_Ouvrage  013EC_Localisation  \
# 0  413812        NaN            NaN                 NaN
# 1  414373        NaN            NaN                 NaN
# 2  415018        NaN            NaN                 NaN
# 3  415245        NaN            NaN                 NaN
# 4  415707        NaN            NaN                 NaN
#
#    014EC_Mode Constructif      Nom                AI                AS  \
# 0                     NaN  25x80cm  1,12999999999993  1,92999999999993
# 1                     NaN  25x80cm  1,12999999999993  1,92999999999993
# 2                     NaN  25x80cm  1,12999999999993  1,92999999999993
# 3                     NaN  25x80cm  1,12999999999993  1,92999999999993
# 4                     NaN  25x80cm  1,12999999999993  1,92999999999993
#
#       Hauteur totale            Hauteur  ...  IfcExportAs  A-Code  bstalp  \
# 0  0,800000000000001  0,800000000000004  ...          NaN     NaN    0,25
# 1  0,800000000000001                0,8  ...          NaN     NaN    0,25
# 2                0,8  0,800000000000004  ...          NaN     NaN    0,25
# 3                0,8  0,800000000000005  ...          NaN     NaN    0,25
# 4                0,8                0,8  ...          NaN     NaN    0,25
#
#    hstalp Code de l'ouvrage  VCF_Codification_MCMT  VCF_Codification  Beams  \
# 0     0,8               NaN                    NaN               NaN      0
# 1     0,8               NaN                    NaN               NaN      0
# 2     0,8               NaN                    NaN               NaN      0
# 3     0,8               NaN                    NaN               NaN      0
# 4     0,8               NaN                    NaN               NaN      0
#
#      h     b
# 0  0,8  0,25
# 1  0,8  0,25
# 2  0,8  0,25
# 3  0,8  0,25
# 4  0,8  0,25
#
# [5 rows x 100 columns]
# Chargé : /Users/fabiancordenod/code/fqbq69/BIMpredict-/raw_data/maquette12/poutres12.csv (17 lignes, 104 colonnes)
#        Id  011EC_Lot  012EC_Ouvrage  013EC_Localisation  \
# 0  441370        NaN            NaN                 NaN
# 1  441410        NaN            NaN                 NaN
# 2  441439        NaN            NaN                 NaN
# 3  441484        NaN            NaN                 NaN
# 4  441512        NaN            NaN                 NaN
#
#    014EC_Mode Constructif      Nom                 AI                AS  \
# 0                     NaN  25x80cm  0,579999999999915  1,37999999999992
# 1                     NaN  25x80cm  0,579999999999915  1,37999999999992
# 2                     NaN  25x80cm  0,579999999999916  1,37999999999992
# 3                     NaN  25x80cm  0,579999999999915  1,37999999999992
# 4                     NaN  25x80cm  0,579999999999915  1,37999999999992
#
#   Hauteur totale            Hauteur  ...  hstalp  Code de l'ouvrage  \
# 0            0,8  0,800000000000002  ...     0,8                NaN
# 1            0,8  0,800000000000002  ...     0,8                NaN
# 2            0,8                0,8  ...     0,8                NaN
# 3            0,8  0,800000000000002  ...     0,8                NaN
# 4            0,8  0,800000000000002  ...     0,8                NaN
#
#    VCF_Codification_MCMT  VCF_Codification Beams  IfcDescription    h     b  \
# 0                    NaN               NaN     0             NaN  0,8  0,25
# 1                    NaN               NaN     0             NaN  0,8  0,25
# 2                    NaN               NaN     0             NaN  0,8  0,25
# 3                    NaN               NaN     0             NaN  0,8  0,25
# 4                    NaN               NaN     0             NaN  0,8  0,25
#
#    Orientation  Plan de construction
# 0          NaN                   NaN
# 1          NaN                   NaN
# 2          NaN                   NaN
# 3          NaN                   NaN
# 4          NaN                   NaN
#
# [5 rows x 104 columns]
# Chargé : /Users/fabiancordenod/code/fqbq69/BIMpredict-/raw_data/maquette13/poutres13.csv (189 lignes, 98 colonnes)
#        Id 011EC_Lot 012EC_Ouvrage 013EC_Localisation 014EC_Mode Constructif  \
# 0  278183        GO   BANDE NOYEE            COURANT         COULE EN PLACE
# 1  278699        GO   BANDE NOYEE            COURANT         COULE EN PLACE
# 2  278701        GO   BANDE NOYEE            COURANT         COULE EN PLACE
# 3  278703        GO   BANDE NOYEE            COURANT         COULE EN PLACE
# 4  278705        GO   BANDE NOYEE            COURANT         COULE EN PLACE
#
#           Nom                 AI                 AS     Hauteur totale  \
# 0  BN 20x20ht  -125,855017806017  -125,655017806017  0,200000000000007
# 1  BN 20x20ht              13,88              14,15  0,200000000000007
# 2  BN 20x20ht              13,88              14,15  0,200000000000007
# 3  BN 20x20ht              13,88              14,15  0,200000000000007
# 4  BN 20x20ht              13,88              14,15  0,200000000000007
#
#              Hauteur  ...  Code d'assemblage  Marque de type  \
# 0  0,200000000000031  ...                NaN             NaN
# 1  0,270000000000008  ...                NaN             NaN
# 2  0,270000000000008  ...                NaN             NaN
# 3  0,270000000000008  ...                NaN             NaN
# 4  0,270000000000008  ...                NaN             NaN
#
#    Protection contre l'incendie  Coût ECH_hauteur  ECH_largeur  \
# 0                           NaN     0         0,2          0,2
# 1                           NaN     0         0,2          0,2
# 2                           NaN     0         0,2          0,2
# 3                           NaN     0         0,2          0,2
# 4                           NaN     0         0,2          0,2
#
#    Type d'attachement de début  Type d'attachement de fin  Orientation  \
# 0                          NaN                        NaN          NaN
# 1                          NaN                        NaN          NaN
# 2                          NaN                        NaN          NaN
# 3                          NaN                        NaN          NaN
# 4                          4.0                        NaN          NaN
#
#   Plan de construction
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
# [5 rows x 98 columns]
# Chargé : /Users/fabiancordenod/code/fqbq69/BIMpredict-/raw_data/maquette14/poutres14.csv (745 lignes, 147 colonnes)
#         Id 011EC_Lot 012EC_Ouvrage 013EC_Localisation 014EC_Mode Constructif  \
# 0  5594311        GO        POUTRE          EXTERIEUR            PREFA USINE
# 1  5596037        GO        POUTRE          EXTERIEUR            PREFA USINE
# 2  5596109        GO        POUTRE          EXTERIEUR            PREFA USINE
# 3  5597793        GO        POUTRE          EXTERIEUR            PREFA USINE
# 4  5600344        GO        POUTRE          EXTERIEUR            PREFA USINE
#
#                 Nom                  AI                 AS   Hauteur totale  \
# 0  Voute en berceau  -0,966512597766341  0,966512597766341  1,9314289918808
# 1  Voute en berceau  -0,966532591220689  0,966532591220689  1,9314289918808
# 2  Voute en berceau  -0,966512597766358  0,966512597766358  1,9314289918808
# 3         Arc brisé  -0,725820272235935  0,725820272235935  1,9314289918808
# 4         Arc brisé  -0,725820272235935  0,725820272235935  1,9314289918808
#
#             Hauteur  ...  EC.R Fonction  EC.R Batiment  Volume Revit Dynamo  \
# 0  1,93302519553268  ...            NaN            NaN                  NaN
# 1  1,93306518244138  ...            NaN            NaN                  NaN
# 2  1,93302519553272  ...            NaN            NaN                  NaN
# 3  1,45164054447187  ...            NaN            NaN                  NaN
# 4  1,45164054447187  ...            NaN            NaN                  NaN
#
#    EC.R Grue Volume Dalle  Surface coffrage V  Surface coffrage H    H  \
# 0        NaN          NaN                 NaN                 NaN  NaN
# 1        NaN          NaN                 NaN                 NaN  NaN
# 2        NaN          NaN                 NaN                 NaN  NaN
# 3        NaN          NaN                 NaN                 NaN  NaN
# 4        NaN          NaN                 NaN                 NaN  NaN
#
#    EC.R Fonction (T)  AIDE pour EC.R Coffrage faces I
# 0                NaN                              NaN
# 1                NaN                              NaN
# 2                NaN                              NaN
# 3                NaN                              NaN
# 4                NaN                              NaN
#
# [5 rows x 147 columns]
# Chargé : /Users/fabiancordenod/code/fqbq69/BIMpredict-/raw_data/maquette15/poutres15.csv (1930 lignes, 148 colonnes)
#         Id 011EC_Lot 012EC_Ouvrage 013EC_Localisation 014EC_Mode Constructif  \
# 0  4000559        GO      LONGRINE          EXTERIEUR            PREFA USINE
# 1  4000723        GO      LONGRINE          EXTERIEUR            PREFA USINE
# 2  4000835        GO      LONGRINE          EXTERIEUR            PREFA USINE
# 3  4000999        GO      LONGRINE          EXTERIEUR            PREFA USINE
# 4  4001125        GO      LONGRINE          EXTERIEUR            PREFA USINE
#
#                             Nom      AI      AS     Hauteur totale  \
# 0  EC_MET_GO_Lg Rect BA_40x60ht   149,7   150,3  0,600000000000002
# 1  EC_MET_GO_Lg Rect BA_40x60ht   149,7   150,3  0,600000000000002
# 2  EC_MET_GO_Lg Rect BA_50x60ht  149,85  150,15  0,600000000000002
# 3  EC_MET_GO_Lg Rect BA_40x60ht   149,7   150,3  0,600000000000002
# 4  EC_MET_GO_Lg Rect BA_40x60ht   149,7   150,3  0,600000000000002
#
#              Hauteur  ...    d  Valeur de la contre-flèche  \
# 0  0,599999999999994  ...  NaN                         NaN
# 1  0,599999999999994  ...  NaN                         NaN
# 2  0,300000000000011  ...  NaN                         NaN
# 3  0,599999999999994  ...  NaN                         NaN
# 4  0,599999999999994  ...  NaN                         NaN
#
#    Nombre de montants    W   tw    k   bf   tf   kr   tr
# 0                 NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1                 NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2                 NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3                 NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4                 NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 148 columns]
# Chargé : /Users/fabiancordenod/code/fqbq69/BIMpredict-/raw_data/maquette16/poutres16.csv (1158 lignes, 118 colonnes)
#         Id 011EC_Lot 012EC_Ouvrage 013EC_Localisation 014EC_Mode Constructif  \
# 0  1673240        GO      LONGRINE          INTERIEUR                 COFFRE
# 1  1673242        GO      LONGRINE          INTERIEUR                 COFFRE
# 2  1673246        GO      LONGRINE          INTERIEUR                 COFFRE
# 3  1673250        GO      LONGRINE          INTERIEUR                 COFFRE
# 4  1673385        GO        POUTRE          INTERIEUR         PREFA CHANTIER
#
#         Nom                  AI                 AS Hauteur totale  \
# 0  LG 30x70               -0,35               0,35            0,7
# 1  LG 30x70               -0,35               0,35            0,7
# 2  LG 30x70  -0,225000000000087  0,225000000000087            0,7
# 3  LG 30x70               -0,35               0,35            0,7
# 4  Po 20x50               -0,25               0,25            0,5
#
#              Hauteur  ...  Congé de l'âme  Effacer la hauteur de l'âme  \
# 0                0,7  ...             NaN                          NaN
# 1                0,7  ...             NaN                          NaN
# 2  0,450000000000175  ...             NaN                          NaN
# 3                0,7  ...             NaN                          NaN
# 4                0,5  ...             NaN                          NaN
#
#    Zone de cisaillement - axe faible  Module d'élasticité - axe fort  \
# 0                                NaN                             NaN
# 1                                NaN                             NaN
# 2                                NaN                             NaN
# 3                                NaN                             NaN
# 4                                NaN                             NaN
#
#   Périmètre  Zone de cisaillement - axe fort  Angle des axes principaux  \
# 0       NaN                              NaN                        NaN
# 1       NaN                              NaN                        NaN
# 2       NaN                              NaN                        NaN
# 3       NaN                              NaN                        NaN
# 4       NaN                              NaN                        NaN
#
#    Moment d'inertie - axe faible  Centre de gravité vertical  \
# 0                            NaN                         NaN
# 1                            NaN                         NaN
# 2                            NaN                         NaN
# 3                            NaN                         NaN
# 4                            NaN                         NaN
#
#    Diamètre du boulon
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#
# [5 rows x 118 columns]
# Chargé : /Users/fabiancordenod/code/fqbq69/BIMpredict-/raw_data/maquette17/poutres17.csv (90 lignes, 84 colonnes)
#         Id 011EC_Lot    012EC_Ouvrage 013EC_Localisation  \
# 0  1620723        GO  SEMELLE FILANTE            COURANT
# 1  1621222        GO  SEMELLE FILANTE            COURANT
# 2  1621224        GO  SEMELLE FILANTE            COURANT
# 3  1621837        GO  SEMELLE FILANTE            COURANT
# 4  1621839        GO  SEMELLE FILANTE            COURANT
#
#   014EC_Mode Constructif                   Nom      AI     AS Hauteur totale  \
# 0   COULE PLEINE FOUILLE  ECRL_Semelle filante  -0,175  0,175           0,35
# 1   COULE PLEINE FOUILLE  ECRL_Semelle filante  -0,175  0,175           0,35
# 2   COULE PLEINE FOUILLE  ECRL_Semelle filante  -0,175  0,175           0,35
# 3   COULE PLEINE FOUILLE  ECRL_Semelle filante   -0,15   0,15            0,3
# 4   COULE PLEINE FOUILLE  ECRL_Semelle filante   -0,15   0,15            0,3
#
#   Hauteur  ...  Commentaires du type  Marque de type  Fabricant  URL  \
# 0    0,35  ...                   NaN             NaN        NaN  NaN
# 1    0,35  ...                   NaN             NaN        NaN  NaN
# 2    0,35  ...                   NaN             NaN        NaN  NaN
# 3     0,3  ...                   NaN             NaN        NaN  NaN
# 4     0,3  ...                   NaN             NaN        NaN  NaN
#
#   Identifiant du nom de la coupe  Note d'identification  \
# 0                            NaN                    NaN
# 1                            NaN                    NaN
# 2                            NaN                    NaN
# 3                            NaN                    NaN
# 4                            NaN                    NaN
#
#    Type d'attachement de début    b    h  Type d'attachement de fin
# 0                          NaN  NaN  NaN                        NaN
# 1                          NaN  NaN  NaN                        NaN
# 2                          NaN  NaN  NaN                        NaN
# 3                          NaN  NaN  NaN                        NaN
# 4                          NaN  NaN  NaN                        NaN
#
# [5 rows x 84 columns]
# Chargé : /Users/fabiancordenod/code/fqbq69/BIMpredict-/raw_data/maquette18/poutres18.csv (208 lignes, 90 colonnes)
#         Id 011EC_Lot 012EC_Ouvrage 013EC_Localisation 014EC_Mode Constructif  \
# 0  1104266        GO        POUTRE            COURANT         COULE EN PLACE
# 1  1104443        GO        POUTRE          INTERIEUR            PREFA USINE
# 2  1104590        GO        POUTRE          INTERIEUR            PREFA USINE
# 3  1104612        GO        POUTRE          INTERIEUR            PREFA USINE
# 4  1104628        GO        POUTRE          INTERIEUR            PREFA USINE
#
#          Nom                  AI                 AS     Hauteur totale  \
# 0  100x55 ht  -0,155000000000001  0,155000000000001  0,549999999999999
# 1   70x55 ht  -0,155000000000001  0,155000000000001  0,549999999999999
# 2   70x55 ht  -0,155000000000001  0,155000000000001  0,549999999999999
# 3   70x55 ht  -0,155000000000001  0,155000000000001  0,549999999999999
# 4   70x55 ht  -0,155000000000001  0,155000000000001  0,549999999999999
#
#              Hauteur  ...  Identifiant du nom de la coupe  Modèle  \
# 0  0,310000000000002  ...                             NaN     NaN
# 1  0,310000000000002  ...                             NaN     NaN
# 2  0,310000000000002  ...                             NaN     NaN
# 3  0,310000000000002  ...                             NaN     NaN
# 4  0,310000000000002  ...                             NaN     NaN
#
#    Image du type  Forme de coupe Numéro OmniClass     h    b  Description  \
# 0        <Aucun>               0              NaN  0,55    1          NaN
# 1        <Aucun>               0              NaN  0,55  0,7          NaN
# 2        <Aucun>               0              NaN  0,55  0,7          NaN
# 3        <Aucun>               0              NaN  0,55  0,7          NaN
# 4        <Aucun>               0              NaN  0,55  0,7          NaN
#
#    URL  Type d'attachement de début
# 0  NaN                          NaN
# 1  NaN                          4.0
# 2  NaN                          4.0
# 3  NaN                          4.0
# 4  NaN                          4.0
#
# [5 rows x 90 columns]
# Chargé : /Users/fabiancordenod/code/fqbq69/BIMpredict-/raw_data/maquette19/poutres19.csv (1632 lignes, 144 colonnes)
#         Id 011EC_Lot 012EC_Ouvrage 013EC_Localisation 014EC_Mode Constructif  \
# 0  3483924        GO        POUTRE            COURANT         COULE EN PLACE
# 1  3490394        GO        POUTRE            COURANT         COULE EN PLACE
# 2  3490409        GO        POUTRE            COURANT         COULE EN PLACE
# 3  3490423        GO        POUTRE            COURANT         COULE EN PLACE
# 4  3490437        GO        POUTRE            COURANT         COULE EN PLACE
#
#                    Nom                  AI                 AS  \
# 0  Poutre Parametrable  -0,150000000000001  0,150000000000001
# 1  Poutre Parametrable  -0,150000000000001  0,150000000000001
# 2  Poutre Parametrable  -0,150000000000001  0,150000000000001
# 3  Poutre Parametrable  -0,150000000000001  0,150000000000001
# 4  Poutre Parametrable  -0,159999999999998  0,159999999999998
#
#       Hauteur totale            Hauteur  ...  Centre de gravité horizontal  \
# 0  0,500000000000001  0,300000000000001  ...                           NaN
# 1  0,500000000000001  0,300000000000001  ...                           NaN
# 2  0,500000000000001  0,300000000000001  ...                           NaN
# 3  0,500000000000001  0,300000000000001  ...                           NaN
# 4  0,520000000000001  0,319999999999997  ...                           NaN
#
#    GOE-Platine Gauche  GOE-Epaisseur de la dalle  GOE-Platine Droite  \
# 0                 NaN                        NaN                 NaN
# 1                 NaN                        NaN                 NaN
# 2                 NaN                        NaN                 NaN
# 3                 NaN                        NaN                 NaN
# 4                 NaN                        NaN                 NaN
#
#   Ht Retombée  Réduction du joint de début  Décalage décroché D  \
# 0         NaN                          NaN                  NaN
# 1         NaN                          NaN                  NaN
# 2         NaN                          NaN                  NaN
# 3         NaN                          NaN                  NaN
# 4         NaN                          NaN                  NaN
#
#    Décalage décroché G  Se déplace avec les éléments voisins  \
# 0                  NaN                                   NaN
# 1                  NaN                                   NaN
# 2                  NaN                                   NaN
# 3                  NaN                                   NaN
# 4                  NaN                                   NaN
#
#    Enrobage d'armature
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
# [5 rows x 144 columns]
# Chargé : /Users/fabiancordenod/code/fqbq69/BIMpredict-/raw_data/maquette20/poutres20.csv (31 lignes, 84 colonnes)
#         Id 011EC_Lot 012EC_Ouvrage 013EC_Localisation 014EC_Mode Constructif  \
# 0  1705576        GO        POUTRE          INTERIEUR         COULE EN PLACE
# 1  1705620        GO        POUTRE          INTERIEUR         COULE EN PLACE
# 2  1706693        GO        POUTRE          INTERIEUR                  METAL
# 3  1706695        GO        POUTRE          INTERIEUR                  METAL
# 4  1706697        GO        POUTRE          INTERIEUR                  METAL
#
#                    Nom                   AI                  AS  \
# 0  ECRL_Poutre_20x80ht                 -0,4                 0,4
# 1  ECRL_Poutre_20x80ht                 -0,4                 0,4
# 2  ECRL_Poutre_30x58ht  -0,0985000000000009  0,0985000000000009
# 3  ECRL_Poutre_30x58ht  -0,0985000000000009  0,0985000000000009
# 4  ECRL_Poutre_30x58ht  -0,0985000000000009  0,0985000000000009
#
#   Hauteur totale            Hauteur  ...  Note d'identification  \
# 0            0,8                0,8  ...                    NaN
# 1            0,8                0,8  ...                    NaN
# 2           0,58  0,197000000000002  ...                    NaN
# 3           0,58  0,197000000000002  ...                    NaN
# 4           0,58  0,197000000000002  ...                    NaN
#
#    Protection contre l'incendie  Nom de code  Coût  \
# 0                           NaN          NaN     0
# 1                           NaN          NaN     0
# 2                           NaN          NaN     0
# 3                           NaN          NaN     0
# 4                           NaN          NaN     0
#
#   Description de l'assemblage  Identifiant du nom de la coupe  Forme de coupe  \
# 0                         NaN                             NaN               0
# 1                         NaN                             NaN               0
# 2                         NaN                             NaN               0
# 3                         NaN                             NaN               0
# 4                         NaN                             NaN               0
#
#    Type d'attachement de début  Type d'attachement de fin  Largeur
# 0                          NaN                        NaN      NaN
# 1                          NaN                        NaN      NaN
# 2                          4.0                        NaN      NaN
# 3                          4.0                        NaN      NaN
# 4                          NaN                        4.0      NaN
#
# [5 rows x 84 columns]
# Chargé : /Users/fabiancordenod/code/fqbq69/BIMpredict-/raw_data/maquette21/poutres21.csv (70 lignes, 82 colonnes)
#         Id 011EC_Lot 012EC_Ouvrage 013EC_Localisation 014EC_Mode Constructif  \
# 0  1652133        GO        POUTRE          INTERIEUR         PREFA CHANTIER
# 1  1652205        GO        POUTRE          INTERIEUR         PREFA CHANTIER
# 2  1652244        GO        POUTRE          INTERIEUR         PREFA CHANTIER
# 3  1652303        GO        POUTRE          INTERIEUR         PREFA CHANTIER
# 4  1652453        GO        POUTRE          INTERIEUR         PREFA CHANTIER
#
#                    Nom      AI      AS     Hauteur totale             Hauteur  \
# 0  ECRL_Poutre_30x30ht  213,85  214,15  0,300000000000001   0,299999999999983
# 1  ECRL_Poutre_30x30ht  213,85  214,15  0,300000000000001   0,299999999999983
# 2  ECRL_Poutre_30x30ht  213,95  214,05  0,300000000000001  0,0999999999999943
# 3  ECRL_Poutre_30x30ht  213,85  214,15  0,300000000000001   0,299999999999983
# 4  ECRL_Poutre_30x30ht  213,85  214,15  0,300000000000001   0,299999999999983
#
#    ...  Protection contre l'incendie  Identifiant du nom de la coupe  \
# 0  ...                           NaN                             NaN
# 1  ...                           NaN                             NaN
# 2  ...                           NaN                             NaN
# 3  ...                           NaN                             NaN
# 4  ...                           NaN                             NaN
#
#    Description    b Nom de code  Commentaires du type  Note d'identification  \
# 0          NaN  0,3         NaN                   NaN                    NaN
# 1          NaN  0,3         NaN                   NaN                    NaN
# 2          NaN  0,3         NaN                   NaN                    NaN
# 3          NaN  0,3         NaN                   NaN                    NaN
# 4          NaN  0,3         NaN                   NaN                    NaN
#
#    Fabricant  Image du type  Type d'attachement de fin
# 0        NaN        <Aucun>                        NaN
# 1        NaN        <Aucun>                        NaN
# ...
# 1               0,45  0,250000000000002  ...     0          NaN
# 2               0,57               0,57  ...     0          NaN
# 3  0,679999999999999  0,480000000000006  ...     0          NaN
# 4                0,2  0,200000000000002  ...     0          NaN
#
#    IFCExportType  ND_Code ZoneName  str_b  str_h  Orientation  \
# 0            NaN      PTE      NaN   0,25   0,45          NaN
# 1            NaN      PTE      NaN   0,25   0,45          NaN
# 2            NaN      PTE      NaN   0,18   0,57          NaN
# 3            NaN      PTE      NaN    0,2   0,68          NaN
# 4            NaN      NaN      NaN    0,4    0,2          NaN
#
#    Plan de construction  Type d'attachement de début
# 0                   NaN                          NaN
# 1                   NaN                          NaN
# 2                   NaN                          NaN
# 3                   NaN                          NaN
# 4                   NaN                          NaN
#
# [5 rows x 99 columns]
# Chargé : /Users/fabiancordenod/code/fqbq69/BIMpredict-/raw_data/maquette37/poutres37.csv (566 lignes, 122 colonnes)
#        Id 011EC_Lot 012EC_Ouvrage 013EC_Localisation 014EC_Mode Constructif  \
# 0  656252        GO        POUTRE          INTERIEUR         PREFA CHANTIER
# 1  656278        GO        POUTRE          INTERIEUR         PREFA CHANTIER
# 2  656592        GO        POUTRE          INTERIEUR         PREFA CHANTIER
# 3  656694        GO        POUTRE          INTERIEUR         PREFA CHANTIER
# 4  683858        GO        POUTRE          INTERIEUR         PREFA CHANTIER
#
#        Nom        AI        AS     Hauteur totale             Hauteur  ...  \
# 0  35x81ht  -176,315  -175,685  0,809999999999989   0,630000000000024  ...
# 1  35x81ht  -176,315  -175,685  0,809999999999989   0,630000000000024  ...
# 2  35x81ht  -176,315  -175,685  0,809999999999989   0,630000000000024  ...
# 3  30x81ht  -176,315  -175,685  0,809999999999989   0,630000000000024  ...
# 4  20x82ht   -176,03   -175,97  0,819999999999987  0,0600000000000023  ...
#
#    Largeur du noyau  Décalage d'alvéole  Nombre d'alvéoles  Hauteur du noyau  \
# 0               NaN                 NaN                NaN               NaN
# 1               NaN                 NaN                NaN               NaN
# 2               NaN                 NaN                NaN               NaN
# 3               NaN                 NaN                NaN               NaN
# 4               NaN                 NaN                NaN               NaN
#
#      h   D1   D2   D3   D4   D5
# 0  NaN  NaN  NaN  NaN  NaN  NaN
# 1  NaN  NaN  NaN  NaN  NaN  NaN
# 2  NaN  NaN  NaN  NaN  NaN  NaN
# 3  NaN  NaN  NaN  NaN  NaN  NaN
# 4  NaN  NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 122 columns]
# Chargé : /Users/fabiancordenod/code/fqbq69/BIMpredict-/raw_data/maquette38/poutres38.csv (68 lignes, 91 colonnes)
#         Id 011EC_Lot 012EC_Ouvrage 013EC_Localisation 014EC_Mode Constructif  \
# 0  2949713        GO        POUTRE          INTERIEUR         PREFA CHANTIER
# 1  2949721        GO        POUTRE          INTERIEUR         PREFA CHANTIER
# 2  2949727        GO        POUTRE          INTERIEUR         PREFA CHANTIER
# 3  2949731        GO        POUTRE          INTERIEUR         PREFA CHANTIER
# 4  2949733        GO        POUTRE          INTERIEUR         PREFA CHANTIER
#
#        Nom                   AI                  AS Hauteur totale  \
# 0  45x65ht  -0,0750000000000029  0,0750000000000029           0,65
# 1  45x65ht  -0,0750000000000029  0,0750000000000029           0,65
# 2  45x65ht  -0,0750000000000029  0,0750000000000029           0,65
# 3  45x65ht  -0,0750000000000029  0,0750000000000029           0,65
# 4  45x65ht  -0,0750000000000029  0,0750000000000029           0,65
#
#              Hauteur  ...   Numéro OmniClass  Description de l'assemblage  \
# 0  0,150000000000006  ...  23.25.30.11.14.14                          NaN
# 1  0,150000000000006  ...  23.25.30.11.14.14                          NaN
# 2  0,150000000000006  ...  23.25.30.11.14.14                          NaN
# 3  0,150000000000006  ...  23.25.30.11.14.14                          NaN
# 4  0,150000000000006  ...  23.25.30.11.14.14                          NaN
#
#    Code d'assemblage  Marque de type Protection contre l'incendie  Coût     h  \
# 0                NaN             NaN                          NaN     0  0,65
# 1                NaN             NaN                          NaN     0  0,65
# 2                NaN             NaN                          NaN     0  0,65
# 3                NaN             NaN                          NaN     0  0,65
# 4                NaN             NaN                          NaN     0  0,65
#
#       b  Type d'attachement de fin  Type d'attachement de début
# 0  0,45                        NaN                          NaN
# 1  0,45                        NaN                          NaN
# 2  0,45                        4.0                          NaN
# 3  0,45                        NaN                          NaN
# 4  0,45                        4.0                          NaN
#
# [5 rows x 91 columns]
# Chargé : /Users/fabiancordenod/code/fqbq69/BIMpredict-/raw_data/maquette39/poutres39.csv (286 lignes, 92 colonnes)
#         Id 011EC_Lot 012EC_Ouvrage 013EC_Localisation 014EC_Mode Constructif  \
# 0  1660970        GO   BANDE NOYEE            COURANT         COULE EN PLACE
# 1  1660976        GO   BANDE NOYEE            COURANT         COULE EN PLACE
# 2  1660980        GO   BANDE NOYEE            COURANT         COULE EN PLACE
# 3  1660982        GO   BANDE NOYEE            COURANT         COULE EN PLACE
# 4  1660988        GO   BANDE NOYEE            COURANT         COULE EN PLACE
#
#   Nom                   AI                  AS     Hauteur totale  \
# 0  BN  -0,0999999999999946  0,0999999999999946  0,200000000000024
# 1  BN  -0,0999999999999946  0,0999999999999946  0,200000000000024
# 2  BN  -0,0999999999999946  0,0999999999999946  0,200000000000024
# 3  BN  -0,0999999999999946  0,0999999999999946  0,200000000000024
# 4  BN  -0,0999999999999946  0,0999999999999946  0,200000000000024
#
#              Hauteur  ...  Forme de coupe  Titre OmniClass   Numéro OmniClass  \
# 0  0,199999999999989  ...               0            Beams  23.25.30.11.14.14
# 1  0,199999999999989  ...               0            Beams  23.25.30.11.14.14
# 2  0,199999999999989  ...               0            Beams  23.25.30.11.14.14
# 3  0,199999999999989  ...               0            Beams  23.25.30.11.14.14
# 4  0,199999999999989  ...               0            Beams  23.25.30.11.14.14
#
#    Description de l'assemblage Code d'assemblage  Marque de type  \
# 0                          NaN               NaN             NaN
# 1                          NaN               NaN             NaN
# 2                          NaN               NaN             NaN
# 3                          NaN               NaN             NaN
# 4                          NaN               NaN             NaN
#
#    Protection contre l'incendie  Coût  Type d'attachement de fin  \
# 0                           NaN     0                        NaN
# 1                           NaN     0                        NaN
# 2                           NaN     0                        4.0
# 3                           NaN     0                        NaN
# 4                           NaN     0                        NaN
#
#    Hauteur Poutre
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 92 columns]
# Chargé : /Users/fabiancordenod/code/fqbq69/BIMpredict-/raw_data/maquette40/poutres40.csv (778 lignes, 93 colonnes)
#        Id 011EC_Lot 012EC_Ouvrage 013EC_Localisation 014EC_Mode Constructif  \
# 0  822465        GO        POUTRE          INTERIEUR         PREFA CHANTIER
# 1  822610        GO        POUTRE          INTERIEUR         PREFA CHANTIER
# 2  823043        GO   BANDE NOYEE            COURANT         COULE EN PLACE
# 3  823110        GO   BANDE NOYEE            COURANT         COULE EN PLACE
# 4  823289        GO   BANDE NOYEE            COURANT         COULE EN PLACE
#
#        Nom                  AI                 AS Hauteur totale  \
# 0  30x60ht  -0,200000000000001  0,200000000000001            0,6
# 1  25x50ht  -0,150000000000001  0,150000000000001            0,5
# 2  30x20ht                -0,1                0,1            0,2
# 3  30x20ht                -0,1                0,1            0,2
# 4  30x20ht                -0,1                0,1            0,2
#
#              Hauteur  ...  Forme de coupe  Titre OmniClass  Numéro OmniClass  \
# 0  0,400000000000002  ...               0              NaN               NaN
# 1  0,300000000000002  ...               0              NaN               NaN
# 2                0,2  ...               0              NaN               NaN
# 3                0,2  ...               0              NaN               NaN
# 4                0,2  ...               0              NaN               NaN
#
#    Description de l'assemblage Code d'assemblage  Marque de type  \
# 0                          NaN               NaN             NaN
# 1                          NaN               NaN             NaN
# 2                          NaN               NaN             NaN
# 3                          NaN               NaN             NaN
# 4                          NaN               NaN             NaN
#
#    Protection contre l'incendie  Coût    h     b
# 0                           NaN     0  0,6   0,3
# 1                           NaN     0  0,5  0,25
# 2                           NaN     0  0,2   0,3
# 3                           NaN     0  0,2   0,3
# 4                           NaN     0  0,2   0,3
#
# [5 rows x 93 columns]
# Chargé : /Users/fabiancordenod/code/fqbq69/BIMpredict-/raw_data/maquette41/poutres41.csv (152 lignes, 93 colonnes)
#        Id 011EC_Lot 012EC_Ouvrage 013EC_Localisation 014EC_Mode Constructif  \
# 0  570797        GO   BANDE NOYEE            COURANT         COULE EN PLACE
# 1  570799        GO   BANDE NOYEE            COURANT         COULE EN PLACE
# 2  570801        GO   BANDE NOYEE            COURANT         COULE EN PLACE
# 3  570803        GO   BANDE NOYEE            COURANT         COULE EN PLACE
# 4  570805        GO   BANDE NOYEE            COURANT         COULE EN PLACE
#
#   Nom                 AI                 AS Hauteur totale Hauteur  ...  \
# 0  BN  0,020000000000003  0,220000000000003            0,2     0,2  ...
# 1  BN  0,020000000000003  0,220000000000003            0,2     0,2  ...
# 2  BN  0,020000000000003  0,220000000000003            0,2     0,2  ...
# 3  BN  0,020000000000003  0,220000000000003            0,2     0,2  ...
# 4  BN  0,020000000000003  0,220000000000003            0,2     0,2  ...
#
#    Titre OmniClass   Numéro OmniClass  Description de l'assemblage  \
# 0            Beams  23.25.30.11.14.14                          NaN
# 1            Beams  23.25.30.11.14.14                          NaN
# 2            Beams  23.25.30.11.14.14                          NaN
# 3            Beams  23.25.30.11.14.14                          NaN
# 4            Beams  23.25.30.11.14.14                          NaN
#
#    Code d'assemblage Marque de type  Protection contre l'incendie  Coût  \
# 0                NaN            NaN                           NaN     0
# 1                NaN            NaN                           NaN     0
# 2                NaN            NaN                           NaN     0
# 3                NaN            NaN                           NaN     0
# 4                NaN            NaN                           NaN     0
#
#    ECH_hauteur  ECH_largeur  Type d'attachement de fin
# 0          0,2          0,4                        NaN
# 1          0,2          0,4                        NaN
# 2          0,2          0,4                        NaN
# 3          0,2          0,4                        4.0
# 4          0,2          0,4                        NaN
#
# [5 rows x 93 columns]
# Chargé : /Users/fabiancordenod/code/fqbq69/BIMpredict-/raw_data/maquette42/poutres42.csv (303 lignes, 100 colonnes)
#         Id 011EC_Lot 012EC_Ouvrage 013EC_Localisation 014EC_Mode Constructif  \
# 0  4389368        GO        POUTRE            COURANT         PREFA CHANTIER
# 1  4389369        GO        POUTRE            COURANT         COULE EN PLACE
# 2  4390633        GO        POUTRE            COURANT         PREFA CHANTIER
# 3  4391390        GO        POUTRE            COURANT         PREFA CHANTIER
# 4  4391391        GO        POUTRE            COURANT         COULE EN PLACE
#
#                    Nom     AI    AS Hauteur totale Hauteur  ...  Coût  A-Code  \
# 0  ECDA_RDC_PO13_30x50  -0,25  0,25           2,75     0,5  ...     0     NaN
# 1                30x50  -0,25  0,25           2,75     0,5  ...     0     NaN
# 2  ECDA_RDC_PO13_30x50  -0,25  0,25           2,75     0,5  ...     0     NaN
# 3   ECDA_R+1_PO9_30x50  -0,25  0,25           2,75     0,5  ...     0     NaN
# 4                30x50  -0,25  0,25           2,75     0,5  ...     0     NaN
#
#     IfcExportAs  IfcDescription    h    b  Orientation  Plan de construction  \
# 0  IfcBeam.BEAM             NaN  0,5  0,3          NaN                   NaN
# 1  IfcBeam.BEAM             NaN  0,5  0,3          NaN                   NaN
# 2  IfcBeam.BEAM             NaN  0,5  0,3          NaN                   NaN
# 3  IfcBeam.BEAM             NaN  0,5  0,3          NaN                   NaN
# 4  IfcBeam.BEAM             NaN  0,5  0,3          NaN                   NaN
#
#    Type d'attachement de début  Type d'attachement de fin
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
#
# [5 rows x 100 columns]
# Total concaténé : 20727 lignes, 529 colonnes
#        Id 011EC_Lot 012EC_Ouvrage 013EC_Localisation 014EC_Mode Constructif  \
# 0  822465        GO        POUTRE          INTERIEUR         PREFA CHANTIER
# 1  822610        GO        POUTRE          INTERIEUR         PREFA CHANTIER
# 2  823043        GO   BANDE NOYEE            COURANT         COULE EN PLACE
# 3  823110        GO   BANDE NOYEE            COURANT         COULE EN PLACE
# 4  823289        GO   BANDE NOYEE            COURANT         COULE EN PLACE
#
#        Nom                  AI                 AS Hauteur totale  \
# 0  30x60ht  -0,200000000000001  0,200000000000001            0,6
# 1  25x50ht  -0,150000000000001  0,150000000000001            0,5
# 2  30x20ht                -0,1                0,1            0,2
# 3  30x20ht                -0,1                0,1            0,2
# 4  30x20ht                -0,1                0,1            0,2
#
#              Hauteur  ...  Largeur du noyau  Décalage d'alvéole  \
# 0  0,400000000000002  ...               NaN                 NaN
# 1  0,300000000000002  ...               NaN                 NaN
# 2                0,2  ...               NaN                 NaN
# 3                0,2  ...               NaN                 NaN
# 4                0,2  ...               NaN                 NaN
#
#   Nombre d'alvéoles  Hauteur du noyau   D2   D3   D4   D5  Retombé  \
# 0               NaN               NaN  NaN  NaN  NaN  NaN      NaN
# 1               NaN               NaN  NaN  NaN  NaN  NaN      NaN
# 2               NaN               NaN  NaN  NaN  NaN  NaN      NaN
# 3               NaN               NaN  NaN  NaN  NaN  NaN      NaN
# 4               NaN               NaN  NaN  NaN  NaN  NaN      NaN
#
#   Hauteur Poutre
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#
# [5 rows x 529 columns]

# %%
poutres_concat.shape
# Out:
# (20727, 529)

# %%
colonnes_a_garder = [
    "011EC_Lot",
    "012EC_Ouvrage",
    "013EC_Localisation",
    "014EC_Mode Constructif",
    "Epaisseur",
    "Sols en intersection",
    "Sols coupés (u)",
    "Sols coupants (u)",
    "Sol au-dessus",
    "Sol en-dessous",
    "Fenêtres",
    "Portes",
    "Ouvertures",
    "Murs imbriqués",
    "Mur multicouche",
    "Profil modifié",
    "Extension inférieure",
    "Extension supérieure",
    "Partie inférieure attachée",
    "Partie supérieure attachée",
    "Décalage supérieur",
    "Décalage inférieur",
    "Matériau structurel",
    "Famille et type"
]

# On ne garde que les colonnes présentes dans le DataFrame
poutres_concat = poutres_concat[[col for col in colonnes_a_garder if col in poutres_concat.columns]]

# %%
import unicodedata
import re

def clean_col(col):
    # Enlever accents
    col = ''.join(c for c in unicodedata.normalize('NFD', col) if unicodedata.category(c) != 'Mn')
    col = col.lower()
    # Remplacer espaces et tirets par _
    col = re.sub(r"[ \-\(\)]", "_", col)
    # Supprimer tout caractère non alphanumérique ou _
    col = re.sub(r"[^a-z0-9_]", "", col)
    # Nettoyer les doubles/triples underscores
    col = re.sub(r"_+", "_", col)
    # Supprimer _ en début/fin
    col = col.strip("_")
    return col

poutres_concat.columns = [clean_col(c) for c in poutres_concat.columns]
print(poutres_concat.columns.tolist())
# Out:
# ['011ec_lot', '012ec_ouvrage', '013ec_localisation', '014ec_mode_constructif', 'sols_en_intersection', 'sols_coupes_u', 'sols_coupants_u', 'sol_au_dessus', 'sol_en_dessous', 'materiau_structurel', 'famille_et_type']

# %%
targets = [
    "011ec_lot",
    "012ec_ouvrage",
    "013ec_localisation",
    "014ec_mode_constructif"
]

# Garder seulement les targets présents dans le DataFrame
targets_in_df = [col for col in targets if col in poutres_concat.columns]

if not targets_in_df:
    raise ValueError(f"Aucune colonne cible trouvée dans poutres_concat. Colonnes disponibles : {poutres_concat.columns.tolist()}")

# X et y_multi
X = poutres_concat.drop(columns=targets_in_df)
y_multi = poutres_concat[targets_in_df]

if X.shape[1] == 0:
    raise ValueError("Aucune variable explicative disponible après suppression des cibles. Vérifiez vos colonnes.")

num_features = X.select_dtypes(include=['int64', 'float64']).columns.tolist()
cat_features = X.select_dtypes(include=['object', 'category']).columns.tolist()

# Pipeline de prétraitement
preprocessor = ColumnTransformer(
    transformers=[
        ('num', Pipeline([
            ('imputer', SimpleImputer(strategy='mean')),
            ('scaler', StandardScaler())
        ]), num_features),
        ('cat', Pipeline([
            ('imputer', SimpleImputer(strategy='most_frequent')),
            ('encoder', OneHotEncoder(handle_unknown='ignore'))
        ]), cat_features)
    ]
)

# Pipeline complet avec MultiOutputClassifier et KNN
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('model', MultiOutputClassifier(KNeighborsClassifier(n_neighbors=10)))
])

# Split train/test
X_train, X_test, y_train, y_test = train_test_split(X, y_multi, test_size=0.2, random_state=42)

# Supprimer les lignes avec NaN dans les targets (train et test)
train_notna = y_train.notna().all(axis=1)
test_notna = y_test.notna().all(axis=1)
X_train, y_train = X_train[train_notna], y_train[train_notna]
X_test, y_test = X_test[test_notna], y_test[test_notna]

# Entraînement
pipeline.fit(X_train, y_train)

# Prédiction et score
y_pred = pipeline.predict(X_test)
print("Accuracy moyenne multi-label :", (y_pred == y_test.values).mean())
# Out:
# Accuracy moyenne multi-label : 0.9474159488746874

# %%
print("Accuracy calculée sur", len(y_test), "échantillons.")
# Out:
# Accuracy calculée sur 3599 échantillons.

# %%
from sklearn.metrics import f1_score

# Calculer le F1-score pour chaque colonne (target) séparément
f1_micro_list = []
f1_macro_list = []
for i, col in enumerate(y_test.columns):
	f1_micro_list.append(f1_score(y_test.iloc[:, i], y_pred[:, i], average='micro'))
	f1_macro_list.append(f1_score(y_test.iloc[:, i], y_pred[:, i], average='macro'))

# Moyenne des scores F1 sur toutes les cibles
f1_micro_mean = np.mean(f1_micro_list)
f1_macro_mean = np.mean(f1_macro_list)

print(f"F1 micro (moyenne par cible): {f1_micro_mean:.4f}")
print(f"F1 macro (moyenne par cible): {f1_macro_mean:.4f}")
# Out:
# F1 micro (moyenne par cible): 0.9474
# F1 macro (moyenne par cible): 0.8484

# %%
import pandas as pd
from sklearn.metrics import f1_score

# Calculer le F1-score pour chaque colonne (target) séparément
f1_per_label = []
for i, col in enumerate(y_test.columns):
    f1_per_label.append(f1_score(y_test.iloc[:, i], y_pred[:, i], average='macro'))

# Récupérer les noms de labels
label_names = list(y_test.columns)

# Construire un DataFrame pour lecture facile
f1_report = pd.DataFrame({
    'Label': label_names,
    'F1-score': f1_per_label
})

# Trier du pire au meilleur
f1_report = f1_report.sort_values(by='F1-score')

# Afficher
print(f1_report)
# Out:
#                     Label  F1-score
# 2      013ec_localisation  0.671067
# 1           012ec_ouvrage  0.793641
# 3  014ec_mode_constructif  0.929021
# 0               011ec_lot  1.000000

# %%
import matplotlib.pyplot as plt

for i, col in enumerate(y_test.columns):
    plt.figure(figsize=(6,3))
    pd.Series(y_test.iloc[:, i]).value_counts().sort_index().plot(kind='bar', alpha=0.5, label='Vrai')
    pd.Series(y_pred[:, i]).value_counts().sort_index().plot(kind='bar', alpha=0.5, label='Prédit')
    plt.title(f"Distribution des classes : {col}")
    plt.legend()
    plt.show()
