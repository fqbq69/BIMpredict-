# %%
import os
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.multioutput import MultiOutputClassifier
from sklearn.metrics import accuracy_score, mean_squared_error

# %%
base_dir = "/Users/fabiancordenod/code/fqbq69/BIMpredict-/raw_data"

dfs = []
for i in range(1, 7):
    poteaux_path = os.path.join(base_dir, f"maquette{i}", f"poteaux{i}.csv")
    if os.path.exists(poteaux_path):
        with open(poteaux_path, encoding="utf-8") as f:
            for idx, line in enumerate(f):
                if line.startswith("Id;"):
                    header_row = idx
                    break
        try:
            df = pd.read_csv(poteaux_path, sep=';', header=header_row)
            dfs.append(df)
            print(f"Chargé : {poteaux_path} ({df.shape[0]} lignes, {df.shape[1]} colonnes)")
            print(df.head())
        except Exception as e:
            print(f"Erreur de parsing : {poteaux_path} -> {e}")
    else:
        print(f"Fichier non trouvé : {poteaux_path}")

if dfs:
    poteaux_concat = pd.concat(dfs, ignore_index=True)
    print(f"Total concaténé : {poteaux_concat.shape[0]} lignes, {poteaux_concat.shape[1]} colonnes")
else:
    poteaux_concat = pd.DataFrame()
    print("Aucun fichier murs.csv trouvé.")

poteaux_concat.head()
# Out:
# Chargé : /Users/fabiancordenod/code/fqbq69/BIMpredict-/raw_data/maquette1/poteaux1.csv (215 lignes, 110 colonnes)
#        Id 011EC_Lot         012EC_Ouvrage 013EC_Localisation  \
# 0  846158        GO  POTEAU RECTANGULAIRE                NaN
# 1  846164        GO  POTEAU RECTANGULAIRE                NaN
# 2  846166        GO  POTEAU RECTANGULAIRE                NaN
# 3  846168        GO  POTEAU RECTANGULAIRE                NaN
# 4  846170        GO  POTEAU RECTANGULAIRE                NaN
#
#   014EC_Mode Constructif     Nom    Image  Style de poteau         Catégorie  \
# 0                 BANCHE  110x30  <Aucun>                0  Poteaux porteurs
# 1                 BANCHE  110x30  <Aucun>                0  Poteaux porteurs
# 2                 BANCHE  110x30  <Aucun>                0  Poteaux porteurs
# 3                 BANCHE  110x30  <Aucun>                0  Poteaux porteurs
# 4                 BANCHE  110x30  <Aucun>                0  Poteaux porteurs
#
#    Type prédéfini d'IFC  ...  Identifiant du nom de la coupe  Forme de coupe  \
# 0                   NaN  ...                             NaN               0
# 1                   NaN  ...                             NaN               0
# 2                   NaN  ...                             NaN               0
# 3                   NaN  ...                             NaN               0
# 4                   NaN  ...                             NaN               0
#
#   Titre OmniClass  Numéro OmniClass Description de l'assemblage  \
# 0             NaN               NaN                         NaN
# 1             NaN               NaN                         NaN
# 2             NaN               NaN                         NaN
# 3             NaN               NaN                         NaN
# 4             NaN               NaN                         NaN
#
#   Code d'assemblage Marque de type  Coût    h    b
# 0               NaN            NaN     0  1,1  0,3
# 1               NaN            NaN     0  1,1  0,3
# 2               NaN            NaN     0  1,1  0,3
# 3               NaN            NaN     0  1,1  0,3
# 4               NaN            NaN     0  1,1  0,3
#
# [5 rows x 110 columns]
# Chargé : /Users/fabiancordenod/code/fqbq69/BIMpredict-/raw_data/maquette2/poteaux2.csv (72 lignes, 111 colonnes)
#        Id 011EC_Lot         012EC_Ouvrage 013EC_Localisation  \
# 0  330453        GO  POTEAU RECTANGULAIRE          INTERIEUR
# 1  330471        GO  POTEAU RECTANGULAIRE          EXTERIEUR
# 2  330473        GO  POTEAU RECTANGULAIRE          EXTERIEUR
# 3  332255        GO  POTEAU RECTANGULAIRE          EXTERIEUR
# 4  332261        GO  POTEAU RECTANGULAIRE          INTERIEUR
#
#   014EC_Mode Constructif    Nom    Image  Style de poteau         Catégorie  \
# 0                 BANCHE  25x60  <Aucun>                0  Poteaux porteurs
# 1                 BANCHE  25x60  <Aucun>                0  Poteaux porteurs
# 2                 BANCHE  25x60  <Aucun>                0  Poteaux porteurs
# 3                 BANCHE  25x60  <Aucun>                0  Poteaux porteurs
# 4                 BANCHE  25x60  <Aucun>                0  Poteaux porteurs
#
#    Type prédéfini d'IFC  ...  Identifiant du nom de la coupe  Forme de coupe  \
# 0                   NaN  ...                             NaN               0
# 1                   NaN  ...                             NaN               0
# 2                   NaN  ...                             NaN               0
# 3                   NaN  ...                             NaN               0
# 4                   NaN  ...                             NaN               0
#
#   Titre OmniClass  Numéro OmniClass Description de l'assemblage  \
# 0             NaN               NaN                         NaN
# 1             NaN               NaN                         NaN
# 2             NaN               NaN                         NaN
# 3             NaN               NaN                         NaN
# 4             NaN               NaN                         NaN
#
#   Code d'assemblage Marque de type  Coût    h     b
# 0               NaN            NaN     0  0,6  0,25
# 1               NaN            NaN     0  0,6  0,25
# 2               NaN            NaN     0  0,6  0,25
# 3               NaN            NaN     0  0,6  0,25
# 4               NaN            NaN     0  0,6  0,25
#
# [5 rows x 111 columns]
# Chargé : /Users/fabiancordenod/code/fqbq69/BIMpredict-/raw_data/maquette3/poteaux3.csv (115 lignes, 113 colonnes)
#        Id 011EC_Lot         012EC_Ouvrage 013EC_Localisation  \
# 0  259869        GO  POTEAU RECTANGULAIRE          EXTERIEUR
# 1  259903        GO  POTEAU RECTANGULAIRE          EXTERIEUR
# 2  262581        GO  POTEAU RECTANGULAIRE          EXTERIEUR
# 3  262673        GO  POTEAU RECTANGULAIRE          INTERIEUR
# 4  262685        GO  POTEAU RECTANGULAIRE          INTERIEUR
#
#   014EC_Mode Constructif      Nom    Image  Style de poteau         Catégorie  \
# 0                 BANCHE  500x500  <Aucun>                0  Poteaux porteurs
# 1                 CARTON  400x400  <Aucun>                0  Poteaux porteurs
# 2                 BANCHE  800x290  <Aucun>                0  Poteaux porteurs
# 3                 CARTON  400x400  <Aucun>                0  Poteaux porteurs
# 4                 CARTON  400x400  <Aucun>                0  Poteaux porteurs
#
#    Type prédéfini d'IFC  ...   Numéro OmniClass  Description de l'assemblage  \
# 0                   NaN  ...  23.25.30.11.14.11                          NaN
# 1                   NaN  ...  23.25.30.11.14.11                          NaN
# 2                   NaN  ...  23.25.30.11.14.11                          NaN
# 3                   NaN  ...  23.25.30.11.14.11                          NaN
# 4                   NaN  ...  23.25.30.11.14.11                          NaN
#
#   Code d'assemblage  Marque de type Coût    h     b  \
# 0               NaN             NaN    0  0,5   0,5
# 1               NaN             NaN    0  0,4   0,4
# 2               NaN             NaN    0  0,8  0,29
# 3               NaN             NaN    0  0,4   0,4
# 4               NaN             NaN    0  0,4   0,4
#
#    Couleur vue détail faible Motif vue détail faible Diamètre
# 0                        NaN                     NaN      NaN
# 1                        NaN                     NaN      NaN
# 2                        NaN                     NaN      NaN
# 3                        NaN                     NaN      NaN
# 4                        NaN                     NaN      NaN
#
# [5 rows x 113 columns]
# Chargé : /Users/fabiancordenod/code/fqbq69/BIMpredict-/raw_data/maquette4/poteaux4.csv (68 lignes, 87 colonnes)
#         Id 011EC_Lot         012EC_Ouvrage 013EC_Localisation  \
# 0  1788118        GO     POTEAU CIRCULAIRE          INTERIEUR
# 1  1788128        GO     POTEAU CIRCULAIRE          INTERIEUR
# 2  1788134        GO     POTEAU CIRCULAIRE          INTERIEUR
# 3  1788142        GO  POTEAU RECTANGULAIRE          INTERIEUR
# 4  1788693        GO     POTEAU CIRCULAIRE          INTERIEUR
#
#   014EC_Mode Constructif              Nom     AI    AS           Hauteur  \
# 0                 CARTON  Ø 30 cm  C35/45  -1,51  1,51              3,02
# 1                 CARTON          Ø 25 cm  -1,61  1,61              3,22
# 2                 CARTON          Ø 25 cm  -1,61  1,61              3,22
# 3                 BANCHE          40 x 40  -2,15  2,15               4,3
# 4                 CARTON  Ø 30 cm  C35/45  -2,13  2,13  4,26000000000001
#
#            Longueur  ...  Nature_Ouvrage  Diamètre poteau    h    b  \
# 0  10,5643044619422  ...     Particulier              0,3  NaN  NaN
# 1  10,5643044619423  ...     Particulier             0,25  NaN  NaN
# 2  10,5643044619423  ...     Particulier             0,25  NaN  NaN
# 3  14,1076115485564  ...             NaN              NaN  0,4  0,4
# 4  13,9763779527559  ...     Particulier              0,3  NaN  NaN
#
#    hauteur_section  largeur_section Décalage de l'attachement à la base  \
# 0              NaN              NaN                                 NaN
# 1              NaN              NaN                                 NaN
# 2              NaN              NaN                                 NaN
# 3              0,4              0,4                                 NaN
# 4              NaN              NaN                                 NaN
#
#    Justification de l'attachement en bas  Décalage de l'attachement en haut  \
# 0                                    NaN                                NaN
# 1                                    NaN                                NaN
# 2                                    NaN                                NaN
# 3                                    NaN                                NaN
# 4                                    NaN                                NaN
#
#   Justification de l'attachement en haut
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
# [5 rows x 87 columns]
# Fichier non trouvé : /Users/fabiancordenod/code/fqbq69/BIMpredict-/raw_data/maquette5/poteaux5.csv
# Chargé : /Users/fabiancordenod/code/fqbq69/BIMpredict-/raw_data/maquette6/poteaux6.csv (115 lignes, 83 colonnes)
#        Id 011EC_Lot         012EC_Ouvrage 013EC_Localisation  \
# 0  259869        GO  POTEAU RECTANGULAIRE          EXTERIEUR
# 1  259903        GO  POTEAU RECTANGULAIRE          EXTERIEUR
# 2  262581        GO  POTEAU RECTANGULAIRE          EXTERIEUR
# 3  262673        GO  POTEAU RECTANGULAIRE          INTERIEUR
# 4  262685        GO  POTEAU RECTANGULAIRE          INTERIEUR
#
#   014EC_Mode Constructif      Nom                 AI                AS  \
# 0                 BANCHE  500x500             -1,675             1,675
# 1                 CARTON  400x400  -1,49999999999999  1,49999999999999
# 2                 BANCHE  800x290             -1,675             1,675
# 3                 CARTON  400x400  -1,51499999999998  1,51499999999998
# 4                 CARTON  400x400  -1,51499999999998  1,51499999999998
#
#             Hauteur          Longueur  ...   Numéro OmniClass  \
# 0              3,35  10,9908136482948  ...  23.25.30.11.14.11
# 1  2,99999999999998  9,84251968504009  ...  23.25.30.11.14.11
# 2              3,35  10,9908136482948  ...  23.25.30.11.14.11
# 3  3,02999999999997  9,94094488189046  ...  23.25.30.11.14.11
# 4  3,02999999999997  9,94094488189046  ...  23.25.30.11.14.11
#
#    Description de l'assemblage  Code d'assemblage  Marque de type  Coût    h  \
# 0                          NaN                NaN             NaN     0  0,5
# 1                          NaN                NaN             NaN     0  0,4
# 2                          NaN                NaN             NaN     0  0,8
# 3                          NaN                NaN             NaN     0  0,4
# 4                          NaN                NaN             NaN     0  0,4
#
#       b  Couleur vue détail faible  Motif vue détail faible Diamètre
# 0   0,5                        NaN                      NaN      NaN
# 1   0,4                        NaN                      NaN      NaN
# 2  0,29                        NaN                      NaN      NaN
# 3   0,4                        NaN                      NaN      NaN
# 4   0,4                        NaN                      NaN      NaN
#
# [5 rows x 83 columns]
# Total concaténé : 585 lignes, 144 colonnes
#        Id 011EC_Lot         012EC_Ouvrage 013EC_Localisation  \
# 0  846158        GO  POTEAU RECTANGULAIRE                NaN
# 1  846164        GO  POTEAU RECTANGULAIRE                NaN
# 2  846166        GO  POTEAU RECTANGULAIRE                NaN
# 3  846168        GO  POTEAU RECTANGULAIRE                NaN
# 4  846170        GO  POTEAU RECTANGULAIRE                NaN
#
#   014EC_Mode Constructif     Nom    Image  Style de poteau         Catégorie  \
# 0                 BANCHE  110x30  <Aucun>                0  Poteaux porteurs
# 1                 BANCHE  110x30  <Aucun>                0  Poteaux porteurs
# 2                 BANCHE  110x30  <Aucun>                0  Poteaux porteurs
# 3                 BANCHE  110x30  <Aucun>                0  Poteaux porteurs
# 4                 BANCHE  110x30  <Aucun>                0  Poteaux porteurs
#
#    Type prédéfini d'IFC  ...  Batiment  NIVEAU_STRUCTURE Nature_Ouvrage  \
# 0                   NaN  ...       NaN               NaN            NaN
# 1                   NaN  ...       NaN               NaN            NaN
# 2                   NaN  ...       NaN               NaN            NaN
# 3                   NaN  ...       NaN               NaN            NaN
# 4                   NaN  ...       NaN               NaN            NaN
#
#    Diamètre poteau hauteur_section largeur_section  \
# 0              NaN             NaN             NaN
# 1              NaN             NaN             NaN
# 2              NaN             NaN             NaN
# 3              NaN             NaN             NaN
# 4              NaN             NaN             NaN
#
#   Décalage de l'attachement à la base  Justification de l'attachement en bas  \
# 0                                 NaN                                    NaN
# 1                                 NaN                                    NaN
# 2                                 NaN                                    NaN
# 3                                 NaN                                    NaN
# 4                                 NaN                                    NaN
#
#   Décalage de l'attachement en haut Justification de l'attachement en haut
# 0                               NaN                                    NaN
# 1                               NaN                                    NaN
# 2                               NaN                                    NaN
# 3                               NaN                                    NaN
# 4                               NaN                                    NaN
#
# [5 rows x 144 columns]

# %%
poteaux_concat.shape
# Out:
# (585, 144)

# %%
print(poteaux_concat)
# Out:
#          Id 011EC_Lot         012EC_Ouvrage 013EC_Localisation  \
# 0    846158        GO  POTEAU RECTANGULAIRE                NaN
# 1    846164        GO  POTEAU RECTANGULAIRE                NaN
# 2    846166        GO  POTEAU RECTANGULAIRE                NaN
# 3    846168        GO  POTEAU RECTANGULAIRE                NaN
# 4    846170        GO  POTEAU RECTANGULAIRE                NaN
# ..      ...       ...                   ...                ...
# 580  385396        GO     POTEAU CIRCULAIRE          EXTERIEUR
# 581  386518        GO     POTEAU CIRCULAIRE          EXTERIEUR
# 582  386528        GO     POTEAU CIRCULAIRE          EXTERIEUR
# 583  386542        GO     POTEAU CIRCULAIRE          EXTERIEUR
# 584  387731        GO  POTEAU RECTANGULAIRE          EXTERIEUR
#
#     014EC_Mode Constructif      Nom    Image  Style de poteau  \
# 0                   BANCHE   110x30  <Aucun>                0
# 1                   BANCHE   110x30  <Aucun>                0
# 2                   BANCHE   110x30  <Aucun>                0
# 3                   BANCHE   110x30  <Aucun>                0
# 4                   BANCHE   110x30  <Aucun>                0
# ..                     ...      ...      ...              ...
# 580                 BANCHE     Ø 30  <Aucun>                0
# 581                 BANCHE     Ø 30  <Aucun>                0
# 582                 BANCHE     Ø 30  <Aucun>                0
# 583                 BANCHE     Ø 30  <Aucun>                0
# 584                 CARTON  400x400  <Aucun>                0
#
#             Catégorie  Type prédéfini d'IFC  ...  Batiment  NIVEAU_STRUCTURE  \
# 0    Poteaux porteurs                   NaN  ...       NaN               NaN
# 1    Poteaux porteurs                   NaN  ...       NaN               NaN
# 2    Poteaux porteurs                   NaN  ...       NaN               NaN
# 3    Poteaux porteurs                   NaN  ...       NaN               NaN
# 4    Poteaux porteurs                   NaN  ...       NaN               NaN
# ..                ...                   ...  ...       ...               ...
# 580  Poteaux porteurs                   NaN  ...       NaN               NaN
# 581  Poteaux porteurs                   NaN  ...       NaN               NaN
# 582  Poteaux porteurs                   NaN  ...       NaN               NaN
# 583  Poteaux porteurs                   NaN  ...       NaN               NaN
# 584  Poteaux porteurs                   NaN  ...       NaN               NaN
#
#     Nature_Ouvrage  Diamètre poteau hauteur_section largeur_section  \
# 0              NaN              NaN             NaN             NaN
# 1              NaN              NaN             NaN             NaN
# 2              NaN              NaN             NaN             NaN
# 3              NaN              NaN             NaN             NaN
# 4              NaN              NaN             NaN             NaN
# ..             ...              ...             ...             ...
# 580            NaN              NaN             NaN             NaN
# 581            NaN              NaN             NaN             NaN
# 582            NaN              NaN             NaN             NaN
# 583            NaN              NaN             NaN             NaN
# 584            NaN              NaN             NaN             NaN
#
#     Décalage de l'attachement à la base  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ..                                  ...
# 580                                 NaN
# 581                                 NaN
# 582                                 NaN
# 583                                 NaN
# 584                                 NaN
#
#      Justification de l'attachement en bas Décalage de l'attachement en haut  \
# 0                                      NaN                               NaN
# 1                                      NaN                               NaN
# 2                                      NaN                               NaN
# 3                                      NaN                               NaN
# 4                                      NaN                               NaN
# ..                                     ...                               ...
# 580                                    NaN                               NaN
# 581                                    NaN                               NaN
# 582                                    NaN                               NaN
# 583                                    NaN                               NaN
# 584                                    NaN                               NaN
#
#     Justification de l'attachement en haut
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ..                                     ...
# 580                                    NaN
# 581                                    NaN
# 582                                    NaN
# 583                                    NaN
# 584                                    NaN
#
# [585 rows x 144 columns]

# %%
colonnes_a_garder = [
    "011EC_Lot",
    "012EC_Ouvrage",
    "013EC_Localisation",
    "014EC_Mode Constructif",
    "Epaisseur",
    "Sols en intersection",
    "Sols coupés (u)",
    "Sols coupants (u)",
    "Sol au-dessus",
    "Sol en-dessous",
    "Fenêtres",
    "Portes",
    "Ouvertures",
    "Murs imbriqués",
    "Mur multicouche",
    "Profil modifié",
    "Extension inférieure",
    "Extension supérieure",
    "Partie inférieure attachée",
    "Partie supérieure attachée",
    "Décalage supérieur",
    "Décalage inférieur",
    "Matériau structurel",
    "Famille et type"
]

# On ne garde que les colonnes présentes dans le DataFrame
poteaux_concat = poteaux_concat[[col for col in colonnes_a_garder if col in poteaux_concat.columns]]

# %%
print(poteaux_concat.columns.tolist())
# Out:
# ['011EC_Lot', '012EC_Ouvrage', '013EC_Localisation', '014EC_Mode Constructif', 'Sols en intersection', 'Sols coupés (u)', 'Sols coupants (u)', 'Partie inférieure attachée', 'Partie supérieure attachée', 'Décalage supérieur', 'Décalage inférieur', 'Matériau structurel', 'Famille et type']

# %%
poteaux_concat
# Out:
#     011ec_lot         012ec_ouvrage 013ec_localisation 014ec_mode_constructif  \
# 0          GO  POTEAU RECTANGULAIRE                NaN                 BANCHE
# 1          GO  POTEAU RECTANGULAIRE                NaN                 BANCHE
# 2          GO  POTEAU RECTANGULAIRE                NaN                 BANCHE
# 3          GO  POTEAU RECTANGULAIRE                NaN                 BANCHE
# 4          GO  POTEAU RECTANGULAIRE                NaN                 BANCHE
# ..        ...                   ...                ...                    ...
# 580        GO     POTEAU CIRCULAIRE          EXTERIEUR                 BANCHE
# 581        GO     POTEAU CIRCULAIRE          EXTERIEUR                 BANCHE
# 582        GO     POTEAU CIRCULAIRE          EXTERIEUR                 BANCHE
# 583        GO     POTEAU CIRCULAIRE          EXTERIEUR                 BANCHE
# 584        GO  POTEAU RECTANGULAIRE          EXTERIEUR                 CARTON
#
#      sols_en_intersection  sols_coupes_u  sols_coupants_u  \
# 0                     NaN            NaN              NaN
# 1                     NaN            NaN              NaN
# 2                     NaN            NaN              NaN
# 3                     NaN            NaN              NaN
# 4                     NaN            NaN              NaN
# ..                    ...            ...              ...
# 580                   0.0            0.0              0.0
# 581                   0.0            0.0              0.0
# 582                   0.0            0.0              0.0
# 583                   0.0            0.0              0.0
# 584                   0.0            0.0              0.0
#
#      partie_inferieure_attachee  partie_superieure_attachee  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
# ..                          ...                         ...
# 580                         0.0                         0.0
# 581                         0.0                         0.0
# 582                         0.0                         0.0
# 583                         0.0                         0.0
# 584                         0.0                         0.0
#
#     decalage_superieur decalage_inferieur           materiau_structurel  \
# 0                -0,75                  0          ECSA - Béton Poteaux
# 1                -0,75                  0          ECSA - Béton Poteaux
# 2                -0,75                  0          ECSA - Béton Poteaux
# 3                -0,75                  0          ECSA - Béton Poteaux
# 4                -0,75                  0          ECSA - Béton Poteaux
# ..                 ...                ...                           ...
# 580               0,51                  0               <Par catégorie>
# 581               0,51                  0               <Par catégorie>
# 582               0,51                  0               <Par catégorie>
# 583               0,51                  0               <Par catégorie>
# 584                  0                  0  Concrete, Cast-in-Place gray
#
#                     famille_et_type
# 0      Poteau rectangulaire: 110x30
# 1      Poteau rectangulaire: 110x30
# 2      Poteau rectangulaire: 110x30
# 3      Poteau rectangulaire: 110x30
# 4      Poteau rectangulaire: 110x30
# ..                              ...
# 580       EIF_STR_Poteau rond: Ø 30
# 581       EIF_STR_Poteau rond: Ø 30
# 582       EIF_STR_Poteau rond: Ø 30
# 583       EIF_STR_Poteau rond: Ø 30
# 584  EIF_STR - Poteau rect: 400x400
#
# [585 rows x 13 columns]

# %%
import unicodedata
import re

def clean_col(col):
    # Enlever accents
    col = ''.join(c for c in unicodedata.normalize('NFD', col) if unicodedata.category(c) != 'Mn')
    col = col.lower()
    # Remplacer espaces et tirets par _
    col = re.sub(r"[ \-\(\)]", "_", col)
    # Supprimer tout caractère non alphanumérique ou _
    col = re.sub(r"[^a-z0-9_]", "", col)
    # Nettoyer les doubles/triples underscores
    col = re.sub(r"_+", "_", col)
    # Supprimer _ en début/fin
    col = col.strip("_")
    return col

poteaux_concat.columns = [clean_col(c) for c in poteaux_concat.columns]
print(poteaux_concat.columns.tolist())
# Out:
# ['011ec_lot', '012ec_ouvrage', '013ec_localisation', '014ec_mode_constructif', 'sols_en_intersection', 'sols_coupes_u', 'sols_coupants_u', 'partie_inferieure_attachee', 'partie_superieure_attachee', 'decalage_superieur', 'decalage_inferieur', 'materiau_structurel', 'famille_et_type']

# %%
# Définir les targets multi-label (adapté aux noms de colonnes nettoyés)
targets = [
    "011ec_lot",
    "012ec_ouvrage",
    "013ec_localisation",
    "014ec_mode_constructif"
]

# Garder seulement les targets présents dans le DataFrame
targets_in_df = [col for col in targets if col in poteaux_concat.columns]

if not targets_in_df:
    raise ValueError(f"Aucune colonne cible trouvée dans murs_concat. Colonnes disponibles : {poteaux_concat.columns.tolist()}")

# X et y_multi
X = poteaux_concat.drop(columns=targets_in_df)
y_multi = poteaux_concat[targets_in_df]

if X.shape[1] == 0:
    raise ValueError("Aucune variable explicative disponible après suppression des cibles. Vérifiez vos colonnes.")

num_features = X.select_dtypes(include=['int64', 'float64']).columns.tolist()
cat_features = X.select_dtypes(include=['object', 'category']).columns.tolist()

# Pipeline de prétraitement
preprocessor = ColumnTransformer(
    transformers=[
        ('num', Pipeline([
            ('imputer', SimpleImputer(strategy='mean')),
            ('scaler', StandardScaler())
        ]), num_features),
        ('cat', Pipeline([
            ('imputer', SimpleImputer(strategy='most_frequent')),
            ('encoder', OneHotEncoder(handle_unknown='ignore'))
        ]), cat_features)
    ]
)

# Pipeline complet avec MultiOutputClassifier
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('model', MultiOutputClassifier(RandomForestClassifier(n_estimators=1000, random_state=42)))
])

# Split train/test
X_train, X_test, y_train, y_test = train_test_split(X, y_multi, test_size=0.2, random_state=42)

# Supprimer les lignes avec NaN dans les targets (train et test)
train_notna = y_train.notna().all(axis=1)
test_notna = y_test.notna().all(axis=1)
X_train, y_train = X_train[train_notna], y_train[train_notna]
X_test, y_test = X_test[test_notna], y_test[test_notna]

# Entraînement
pipeline.fit(X_train, y_train)

# Prédiction et score baseline
y_pred = pipeline.predict(X_test)
print("Accuracy moyenne multi-label :", (y_pred == y_test.values).mean())
# Out:
# Accuracy moyenne multi-label : 0.9787735849056604

# %%
print("Accuracy calculée sur", len(y_test), "échantillons.")
# Out:
# Accuracy calculée sur 106 échantillons.

# %%
poteaux_concat
# Out:
#     011ec_lot         012ec_ouvrage 013ec_localisation 014ec_mode_constructif  \
# 0          GO  POTEAU RECTANGULAIRE                NaN                 BANCHE
# 1          GO  POTEAU RECTANGULAIRE                NaN                 BANCHE
# 2          GO  POTEAU RECTANGULAIRE                NaN                 BANCHE
# 3          GO  POTEAU RECTANGULAIRE                NaN                 BANCHE
# 4          GO  POTEAU RECTANGULAIRE                NaN                 BANCHE
# ..        ...                   ...                ...                    ...
# 580        GO     POTEAU CIRCULAIRE          EXTERIEUR                 BANCHE
# 581        GO     POTEAU CIRCULAIRE          EXTERIEUR                 BANCHE
# 582        GO     POTEAU CIRCULAIRE          EXTERIEUR                 BANCHE
# 583        GO     POTEAU CIRCULAIRE          EXTERIEUR                 BANCHE
# 584        GO  POTEAU RECTANGULAIRE          EXTERIEUR                 CARTON
#
#      sols_en_intersection  sols_coupes_u  sols_coupants_u  \
# 0                     NaN            NaN              NaN
# 1                     NaN            NaN              NaN
# 2                     NaN            NaN              NaN
# 3                     NaN            NaN              NaN
# 4                     NaN            NaN              NaN
# ..                    ...            ...              ...
# 580                   0.0            0.0              0.0
# 581                   0.0            0.0              0.0
# 582                   0.0            0.0              0.0
# 583                   0.0            0.0              0.0
# 584                   0.0            0.0              0.0
#
#      partie_inferieure_attachee  partie_superieure_attachee  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
# ..                          ...                         ...
# 580                         0.0                         0.0
# 581                         0.0                         0.0
# 582                         0.0                         0.0
# 583                         0.0                         0.0
# 584                         0.0                         0.0
#
#     decalage_superieur decalage_inferieur           materiau_structurel  \
# 0                -0,75                  0          ECSA - Béton Poteaux
# 1                -0,75                  0          ECSA - Béton Poteaux
# 2                -0,75                  0          ECSA - Béton Poteaux
# 3                -0,75                  0          ECSA - Béton Poteaux
# 4                -0,75                  0          ECSA - Béton Poteaux
# ..                 ...                ...                           ...
# 580               0,51                  0               <Par catégorie>
# 581               0,51                  0               <Par catégorie>
# 582               0,51                  0               <Par catégorie>
# 583               0,51                  0               <Par catégorie>
# 584                  0                  0  Concrete, Cast-in-Place gray
#
#                     famille_et_type
# 0      Poteau rectangulaire: 110x30
# 1      Poteau rectangulaire: 110x30
# 2      Poteau rectangulaire: 110x30
# 3      Poteau rectangulaire: 110x30
# 4      Poteau rectangulaire: 110x30
# ..                              ...
# 580       EIF_STR_Poteau rond: Ø 30
# 581       EIF_STR_Poteau rond: Ø 30
# 582       EIF_STR_Poteau rond: Ø 30
# 583       EIF_STR_Poteau rond: Ø 30
# 584  EIF_STR - Poteau rect: 400x400
#
# [585 rows x 13 columns]

# %%
from sklearn.metrics import f1_score

# Calculer le F1-score pour chaque colonne (target) séparément
f1_micro_list = []
f1_macro_list = []
for i, col in enumerate(y_test.columns):
	f1_micro_list.append(f1_score(y_test.iloc[:, i], y_pred[:, i], average='micro'))
	f1_macro_list.append(f1_score(y_test.iloc[:, i], y_pred[:, i], average='macro'))

# Moyenne des scores F1 sur toutes les cibles
f1_micro_mean = np.mean(f1_micro_list)
f1_macro_mean = np.mean(f1_macro_list)

print(f"F1 micro (moyenne par cible): {f1_micro_mean:.4f}")
print(f"F1 macro (moyenne par cible): {f1_macro_mean:.4f}")
# Out:
# F1 micro (moyenne par cible): 0.9788
# F1 macro (moyenne par cible): 0.8847

# %%
import pandas as pd
from sklearn.metrics import f1_score

# Calculer le F1-score pour chaque colonne (target) séparément
f1_per_label = []
for i, col in enumerate(y_test.columns):
    f1_per_label.append(f1_score(y_test.iloc[:, i], y_pred[:, i], average='macro'))

# Récupérer les noms de labels
label_names = list(y_test.columns)

# Construire un DataFrame pour lecture facile
f1_report = pd.DataFrame({
    'Label': label_names,
    'F1-score': f1_per_label
})

# Trier du pire au meilleur
f1_report = f1_report.sort_values(by='F1-score')

# Afficher
print(f1_report)
# Out:
#                     Label  F1-score
# 1           012ec_ouvrage  0.745665
# 2      013ec_localisation  0.885824
# 3  014ec_mode_constructif  0.907290
# 0               011ec_lot  1.000000
