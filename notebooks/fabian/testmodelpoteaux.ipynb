# %%
import joblib
import pandas as pd
import unicodedata
import re
import pickle
import os
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.multioutput import MultiOutputClassifier
from sklearn.metrics import accuracy_score, mean_squared_error

# %%
pipeline_path = "/Users/fabiancordenod/code/fqbq69/BIMpredict-/pkl /Random_Forest_optimized.pkl"
pipeline = joblib.load(pipeline_path)

# %%
# Charger le CSV
csv_path = "/Users/fabiancordenod/code/fqbq69/BIMpredict-/datatest/test21020/poteaux21020.csv"
if not os.path.isfile(csv_path):
    print(f"Le fichier n'existe pas : {csv_path}")
    df_test = None
else:
    df_test = pd.read_csv(csv_path, delimiter=';', header=1)

# Nettoyer les noms de colonnes comme à l'entraînement
def clean_col(col):
    col = ''.join(c for c in unicodedata.normalize('NFD', col) if unicodedata.category(c) != 'Mn')
    col = col.lower()
    col = re.sub(r"[ \-\(\)]", "_", col)
    col = re.sub(r"[^a-z0-9_]", "", col)
    col = re.sub(r"_+", "_", col)
    col = col.strip("_")
    return col

if df_test is not None:
    df_test.columns = [clean_col(c) for c in df_test.columns]

# %%
df_test
# Out:
#          id  011ec_lot  012ec_ouvrage  013ec_localisation  \
# 0    983633        NaN            NaN                 NaN
# 1    983668        NaN            NaN                 NaN
# 2    983685        NaN            NaN                 NaN
# 3    983702        NaN            NaN                 NaN
# 4    983729        NaN            NaN                 NaN
# 5    983746        NaN            NaN                 NaN
# 6    983791        NaN            NaN                 NaN
# 7    983811        NaN            NaN                 NaN
# 8    983828        NaN            NaN                 NaN
# 9    983847        NaN            NaN                 NaN
# 10   983866        NaN            NaN                 NaN
# 11   983883        NaN            NaN                 NaN
# 12   983906        NaN            NaN                 NaN
# 13   984319        NaN            NaN                 NaN
# 14   984344        NaN            NaN                 NaN
# ...

# %%
# Les targets à prédire (après nettoyage)
targets = [
    "011ec_lot",
    "012ec_ouvrage",
    "013ec_localisation",
    "014ec_mode_constructif"
]

# Colonnes explicatives (toutes sauf les targets)
features = [col for col in df_test.columns if col not in targets]

# S'assurer que toutes les colonnes sont présentes (inutile ici car on prend celles du df_test)
X_test = df_test[features].copy()

# %%
y_pred = pipeline.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 y_pred = pipeline.predict(X_test)
#
# File ~/.pyenv/versions/3.10.6/envs/BIMpredict2/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:823, in ForestClassifier.predict(self, X)
#     802 def predict(self, X):
#     803     """
#     804     Predict class for X.
#     805
#    (...)
#     821         The predicted classes.
#     822     """
# --> 823     proba = self.predict_proba(X)
#     825     if self.n_outputs_ == 1:
#     826         return self.classes_.take(np.argmax(proba, axis=1), axis=0)
#
# File ~/.pyenv/versions/3.10.6/envs/BIMpredict2/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:865, in ForestClassifier.predict_proba(self, X)
#     863 check_is_fitted(self)
#     864 # Check data
# --> 865 X = self._validate_X_predict(X)
#     867 # Assign chunk of trees to jobs
# ...

# %%
y_pred
# Out:
# array([['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
#        ['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
#        ['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
#        ['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
#        ['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
#        ['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
#        ['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
#        ['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
#        ['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
#        ['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
#        ['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
#        ['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
#        ['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
#        ['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
#        ['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
# ...

# %%
# Les targets à prédire (après nettoyage)
targets = [
    "011ec_lot",
    "012ec_ouvrage",
    "013ec_localisation",
    "014ec_mode_constructif"
]

# Mettre les prédictions dans un DataFrame
df_pred = pd.DataFrame(y_pred, columns=targets)

# Afficher les premières lignes
print(df_pred.head(200))
# Out:
#    011ec_lot         012ec_ouvrage 013ec_localisation 014ec_mode_constructif
# 0         GO  POTEAU RECTANGULAIRE          INTERIEUR                 BANCHE
# 1         GO  POTEAU RECTANGULAIRE          INTERIEUR                 BANCHE
# 2         GO  POTEAU RECTANGULAIRE          INTERIEUR                 BANCHE
# 3         GO  POTEAU RECTANGULAIRE          INTERIEUR                 BANCHE
# 4         GO  POTEAU RECTANGULAIRE          INTERIEUR                 BANCHE
# 5         GO  POTEAU RECTANGULAIRE          INTERIEUR                 BANCHE
# 6         GO  POTEAU RECTANGULAIRE          INTERIEUR                 BANCHE
# 7         GO  POTEAU RECTANGULAIRE          INTERIEUR                 BANCHE
# 8         GO  POTEAU RECTANGULAIRE          INTERIEUR                 BANCHE
# 9         GO  POTEAU RECTANGULAIRE          INTERIEUR                 BANCHE
# 10        GO  POTEAU RECTANGULAIRE          INTERIEUR                 BANCHE
# ...

# %%
df_pred.to_csv("resultats_predictionspoteaux21020.csv", index=False)
