# %%
import pandas as pd
import io

# %%
csv_list = []
with open('raw_data/test.csv','r') as input_file:
    data_str = input_file.read()
    data_array = data_str.split('\n\n')
    for i, smaller_data in enumerate(data_array):
        csv_list.append(smaller_data)

# %%
title = csv_list[1].split("\n",1)[0]
remove_title = csv_list[1].split("\n",1)[1]
remove_title,title
# Out:
# ("Id;011EC_Lot;012EC_Ouvrage;013EC_Localisation;014EC_Mode Constructif;Nom;Murs en intersection;Murs coupés (u);Murs coupés (Ids);Murs coupants (u);Murs coupants (Ids);Poutres en intersection;Poutres coupés (u);Poutres coupés (Ids);Poutres coupants (u);Poutres coupants (Ids);Poteaux en intersection;Poteaux coupés (u);Poteaux coupés (Ids);Poteaux coupants (u);Poteaux coupants (Ids);Ouvertures;Sol multicouche;Profil modifié;Image;Catégorie;Type prédéfini d'IFC;Exporter au format IFC sous;Exporter au format IFC;IfcGUID;A une association;Enrobage d'armature - Face inférieure;Enrobage d'armature - Face supérieure;Enrobage d'armature - Autres faces;Variantes;Volume;Surface;Phase de démolition;Phase de création;Commentaires;Inclinaison;Niveau;Famille et type;Famille;Type;Nom de la famille;Nom du type;ID du type;Structure;Périmètre;Décalage par rapport au niveau;Epaisseur;Lié au volume;Etude de l'élévation à la base;Etude de l'élévation en haut;Epaisseur du porteur;Elévation au niveau du noy
# ...

# %%
pd.read_csv(io.StringIO(remove_title),sep=";")
# Out:
#          Id 011EC_Lot 012EC_Ouvrage 013EC_Localisation 014EC_Mode Constructif  \
# 0   1666807        GO  DALLE PORTEE            COURANT         COULE EN PLACE
# 1   1667912        GO  DALLE PORTEE            COURANT         COULE EN PLACE
# 2   1668659        GO  DALLE PORTEE            COURANT         COULE EN PLACE
# 3   1669717        GO  DALLE PORTEE            COURANT         COULE EN PLACE
# 4   1671060        GO  DALLE PORTEE            COURANT         COULE EN PLACE
# 5   1671807        GO      PLANCHER            COURANT         COULE EN PLACE
# 6   1672171        GO  DALLE PORTEE            COURANT         COULE EN PLACE
# 7   1672476        GO  DALLE PORTEE            COURANT         COULE EN PLACE
# 8   1672878        GO  DALLE PORTEE            COURANT         COULE EN PLACE
# 9   1673956        GO  DALLE PORTEE            COURANT         COULE EN PLACE
# 10  1675910        GO  DALLE PORTEE            COURANT         COULE EN PLACE
# ...

# %%
csv_list2 = []
with open('raw_data/test2.csv','r') as input_file:
    data_str = input_file.read()
    data_array = data_str.split('\n\n')
    for i, smaller_data in enumerate(data_array):
        csv_list2.append(smaller_data)

# %%
title = csv_list2[1].split("\n",1)[0]
remove_title = csv_list2[1].split("\n",1)[1]
remove_title,title
# Out:
# ("Id;011EC_Lot;012EC_Ouvrage;013EC_Localisation;014EC_Mode Constructif;Nom;Murs en intersection;Murs coupés (u);Murs coupés (Ids);Murs coupants (u);Murs coupants (Ids);Poutres en intersection;Poutres coupés (u);Poutres coupés (Ids);Poutres coupants (u);Poutres coupants (Ids);Poteaux en intersection;Poteaux coupés (u);Poteaux coupés (Ids);Poteaux coupants (u);Poteaux coupants (Ids);Ouvertures;Sol multicouche;Profil modifié;Image;Catégorie;Type prédéfini d'IFC;Exporter au format IFC sous;Exporter au format IFC;IfcGUID;A une association;Variantes;Volume;Surface;Phase de démolition;Phase de création;Commentaires;Inclinaison;Niveau;Famille et type;Famille;Type;Nom de la famille;Nom du type;ID du type;Structure;Périmètre;Décalage par rapport au niveau;Epaisseur;Lié au volume;Elévation au niveau du noyau inférieur;Elévation au niveau du noyau supérieur;Elévation en haut;Elévation à la base;Identifiant;Limite de pièce;ECNO_Type_ferraillage;ECNO_Ratio_HA_Surfacique_EXE;ECNO_Ratio_TS_Surfaciqu
# ...

# %%
pd.read_csv(io.StringIO(remove_title),sep=";")
# Out:
#           Id   011EC_Lot 012EC_Ouvrage 013EC_Localisation  \
# 0    2949667          GO      PLANCHER      CAGE ESCALIER
# 1    2949773          GO      PLANCHER            COURANT
# 2    2949788          GO      PLANCHER            COURANT
# 3    2949795          GO      PLANCHER            COURANT
# 4    2949803          GO      PLANCHER            COURANT
# ..       ...         ...           ...                ...
# 136  3359790  ETANCHEITE           CES                CES
# 137  3359839  ETANCHEITE           CES                CES
# 138  3420251          GO        RADIER              FOSSE
# 139  3420301          GO        RADIER            COURANT
# 140  3499699  ETANCHEITE           CES                CES
#
#     014EC_Mode Constructif                            Nom  \
# 0           COULE EN PLACE                 EC_DALLE_BA_23
# 1           COULE EN PLACE                 EC_DALLE_BA_50
# 2           COULE EN PLACE                 EC_DALLE_BA_23
# ...
