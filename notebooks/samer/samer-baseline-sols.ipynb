# %%
import numpy as np
import os
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %%
base_dir = "../../raw_data/"

# %% [markdown]
# ## Trying the Poteaux csv files

# %%
dfs = []
tableau = 'poteaux'
for i in range(1, 7):
    csv_path = os.path.join(base_dir, f"maquette{i}", f"{tableau}{i}.csv")
    if os.path.exists(csv_path):
        # Cherche la ligne d'en-tête réelle
        with open(csv_path, encoding="utf-8") as f:
            for idx, line in enumerate(f):
                if line.startswith("Id;"):
                    header_row = idx
                    break
        try:
            df = pd.read_csv(csv_path, sep=';', decimal=",", header=header_row)
            dfs.append(df)
            print(f"Chargé : {csv_path} ({df.shape[0]} lignes, {df.shape[1]} colonnes)")
            #print(df.head())
        except Exception as e:
            print(f"Erreur de parsing : {csv_path} -> {e}")
    else:
        print(f"Fichier non trouvé : {csv_path}")

if dfs:
    dfs_concat = pd.concat(dfs, ignore_index=True)
    print(f"Total concaténé : {dfs_concat.shape[0]} lignes, {dfs_concat.shape[1]} colonnes")
else:
    dfs_concat = pd.DataFrame()
    print("Aucun fichier murs.csv trouvé.")

dfs_concat.shape
# Out:
# Chargé : ../../raw_data/maquette1/poteaux1.csv (215 lignes, 110 colonnes)
# Chargé : ../../raw_data/maquette2/poteaux2.csv (72 lignes, 111 colonnes)
# Chargé : ../../raw_data/maquette3/poteaux3.csv (115 lignes, 113 colonnes)
# Chargé : ../../raw_data/maquette4/poteaux4.csv (68 lignes, 87 colonnes)
# Fichier non trouvé : ../../raw_data/maquette5/poteaux5.csv
# Chargé : ../../raw_data/maquette6/poteaux6.csv (115 lignes, 83 colonnes)
# Total concaténé : 2867 lignes, 160 colonnes
# (585, 144)

# %%
dfs_concat
# Out:
#          Id 011EC_Lot         012EC_Ouvrage 013EC_Localisation  \
# 0    846158        GO  POTEAU RECTANGULAIRE                NaN
# 1    846164        GO  POTEAU RECTANGULAIRE                NaN
# 2    846166        GO  POTEAU RECTANGULAIRE                NaN
# 3    846168        GO  POTEAU RECTANGULAIRE                NaN
# 4    846170        GO  POTEAU RECTANGULAIRE                NaN
# ..      ...       ...                   ...                ...
# 580  385396        GO     POTEAU CIRCULAIRE          EXTERIEUR
# 581  386518        GO     POTEAU CIRCULAIRE          EXTERIEUR
# 582  386528        GO     POTEAU CIRCULAIRE          EXTERIEUR
# 583  386542        GO     POTEAU CIRCULAIRE          EXTERIEUR
# 584  387731        GO  POTEAU RECTANGULAIRE          EXTERIEUR
#
#     014EC_Mode Constructif      Nom    Image  Style de poteau  \
# 0                   BANCHE   110x30  <Aucun>                0
# 1                   BANCHE   110x30  <Aucun>                0
# 2                   BANCHE   110x30  <Aucun>                0
# 3                   BANCHE   110x30  <Aucun>                0
# 4                   BANCHE   110x30  <Aucun>                0
# ..                     ...      ...      ...              ...
# 580                 BANCHE     Ø 30  <Aucun>                0
# 581                 BANCHE     Ø 30  <Aucun>                0
# 582                 BANCHE     Ø 30  <Aucun>                0
# 583                 BANCHE     Ø 30  <Aucun>                0
# 584                 CARTON  400x400  <Aucun>                0
#
#             Catégorie  Type prédéfini d'IFC  ...  Batiment  NIVEAU_STRUCTURE  \
# 0    Poteaux porteurs                   NaN  ...       NaN               NaN
# 1    Poteaux porteurs                   NaN  ...       NaN               NaN
# 2    Poteaux porteurs                   NaN  ...       NaN               NaN
# 3    Poteaux porteurs                   NaN  ...       NaN               NaN
# 4    Poteaux porteurs                   NaN  ...       NaN               NaN
# ..                ...                   ...  ...       ...               ...
# 580  Poteaux porteurs                   NaN  ...       NaN               NaN
# 581  Poteaux porteurs                   NaN  ...       NaN               NaN
# 582  Poteaux porteurs                   NaN  ...       NaN               NaN
# 583  Poteaux porteurs                   NaN  ...       NaN               NaN
# 584  Poteaux porteurs                   NaN  ...       NaN               NaN
#
#     Nature_Ouvrage  Diamètre poteau hauteur_section largeur_section  \
# 0              NaN              NaN             NaN             NaN
# 1              NaN              NaN             NaN             NaN
# 2              NaN              NaN             NaN             NaN
# 3              NaN              NaN             NaN             NaN
# 4              NaN              NaN             NaN             NaN
# ..             ...              ...             ...             ...
# 580            NaN              NaN             NaN             NaN
# 581            NaN              NaN             NaN             NaN
# 582            NaN              NaN             NaN             NaN
# 583            NaN              NaN             NaN             NaN
# 584            NaN              NaN             NaN             NaN
#
#     Décalage de l'attachement à la base  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ..                                  ...
# 580                                 NaN
# 581                                 NaN
# 582                                 NaN
# 583                                 NaN
# 584                                 NaN
#
#      Justification de l'attachement en bas  Décalage de l'attachement en haut  \
# 0                                      NaN                                NaN
# 1                                      NaN                                NaN
# 2                                      NaN                                NaN
# 3                                      NaN                                NaN
# 4                                      NaN                                NaN
# ..                                     ...                                ...
# 580                                    NaN                                NaN
# 581                                    NaN                                NaN
# 582                                    NaN                                NaN
# 583                                    NaN                                NaN
# 584                                    NaN                                NaN
#
#     Justification de l'attachement en haut
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ..                                     ...
# 580                                    NaN
# 581                                    NaN
# 582                                    NaN
# 583                                    NaN
# 584                                    NaN
#
# [585 rows x 144 columns]

# %% [markdown]
# ### FEATURES SELECTION:

# %%
all_features = [
        "Id", "011EC_Lot", "012EC_Ouvrage", "013EC_Localisation", "014EC_Mode Constructif",
        "Nom", "AI", "AS", "Hauteur", "Longueur",
        "Partie inférieure attachée", "Partie supérieure attachée",
        "Sols en intersection", "Sols coupés (u)", "Sols coupés (Ids)",
        "Sols coupants (u)", "Sols coupants (Ids)", "Poutres en intersection",
        "Poutres coupés (u)", "Poutres coupés (Ids)", "Poutres coupants (u)",
        "Poutres coupants (Ids)", "Matériau structurel", "Marque d'emplacement du poteau",
        "Décalage supérieur", "Décalage inférieur",
        "Longueur", "Sols coupés (Ids)", "Sols coupants (Ids)",
        "Poutres coupés (Ids)", "Poutres coupants (Ids)",
]

df = dfs_concat[all_features]
df.shape
# Out:
# (585, 31)

# %%
uniq = []
for feature in all_features:
    feats = dfs_concat[feature].unique()
    uniq.append(f'{feature} : {len(feats)} +++ : {feats}' )

# %%
uniq
# Out:
# ['Id : 470 +++ : [ 846158  846164  846166  846168  846170  846172  846174  846176  846178\n  846180  846182  846184  846186  846188  846190  846192  846194  846196\n  846198  846200  846202  846224  846226  846228  846230  846232  846234\n  846266 1165467 1165469 1165471 1165473 1165475 1165477 1165479 1165481\n 1165483 1165485 1165487 1165489 1165491 1165493 1165495 1165497 1165499\n 1165501 1165503 1165505 1165507 1165509 1165511 1165513 1165515 1165517\n 1165519 1165521 1165523 1165525 1165529 1165539 1165541 1165543 1165545\n 1165547 1165549 1165551 1165553 1238585 1238587 1238589 1238591 1238593\n 1238595 1238597 1238599 1238601 1238603 1238605 1238607 1238609 1238611\n 1238613 1238615 1238617 1238619 1238621 1238623 1238625 1238627 1238629\n 1238631 1238633 1238635 1238637 1238639 1238641 1238643 1238645 1238647\n 1238649 1238651 1238653 1238655 1400695 1401284 1401540 1401730 1473399\n 1473401 1473403 1473405 1473407 1473409 1473411 1473413 1473415 1473417\n 1473419 1473421 1473423 1473425 1473427 1473429 1473431 1473433 1473435\n 1473437 1473439 1473441 1473443 1473445 1473447 1473449 1473451 1473453\n 1473455 1473457 1473459 1473461 1473463 1473465 1473467 1473469 1473475\n 1473477 1473479 1473481 1473483 1473485 1473487 1473489 1473491 1473493\n 1473495 1473497 1473499 1473501 1473503 1473505 1473507 1473509 1473511\n 1473513 1473515 1473517 1473519 1473521 1473523 1473525 1473527 1473529\n 1473531 1473533 1473535 1473537 1473539 1473541 1473543 1473545 1473551\n 1473553 1473555 1473557 1473559 1473561 1473563 1473565 1473567 1473569\n 1473571 1473573 1473575 1473577 1473579 1473581 1473583 1473585 1473587\n 1473589 1473591 1473593 1473595 1473597 1473599 1473601 1473603 1473605\n 1473607 1473609 1473611 1473613 1473615 1473617 1473619 1473621  330453\n  330471  330473  332255  332261  332263  332457  332459  335702  335704\n  335706  335758  336257  336259  336261  336263  336265  336267  336269\n  336301  337259  337261  337263  337866  337868  337870  337872  337874\n  337876  337878  337910  337936  337938  337940  338979  338981  338983\n  338985  338987  338989  338991  339023  342253  342255  342325  342327\n  557545  557547  713928  713930  737538  737540  766535  766537  766539\n  766541  766543  766545  766553  766555  766567  766569  766571  766579\n  766581  863517  863550  863580  864523  864611  864669  865866  259869\n  259903  262581  262673  262685  269699  269713  269725  269739  269755\n  269789  269811  269859  269891  269907  269917  269931  269956  269970\n  269988  270002  270016  270026  270040  270056  270068  270080  270108\n  270126  270251  270320  270346  270360  270376  270484  270534  273795\n  289009  289010  289691  292923  293030  293040  293054  293064  293154\n  293166  293180  293192  293206  293218  293230  293242  293258  293270\n  293286  293300  293312  293328  293340  293352  293368  303688  303738\n  303752  303766  303790  303837  303853  303867  303881  310820  310821\n  313680  360438  360932  361345  361504  361524  361536  361548  361558\n  361728  361742  361758  361772  361786  361804  361814  361824  361861\n  383047  383061  383073  383083  383095  383107  383314  383326  383354\n  383382  385262  385276  385288  385300  385310  385322  385332  385344\n  385368  385396  386518  386528  386542  387731 1788118 1788128 1788134\n 1788142 1788693 1788697 1788703 1788709 1788713 1788717 1788723 1788729\n 1788803 1789480 1790157 1790163 1790210 1791087 1791099 1791107 1791113\n 1791128 1791136 1791142 1791148 1791154 1791160 1791517 1791523 1791529\n 1791610 1791614 1791618 1791624 1791630 1791636 1791865 1791873 1791881\n 1791899 1791905 1793059 1793402 1793416 1793422 1793497 1793507 1793517\n 1793523 1793557 1793565 1793591 1793601 1793607 1793629 1793643 1793651\n 1794016 1794022 1794028 1794879 1795222 1795461 1795477 1795588 1795594\n 1795598 1795604]',
#  "011EC_Lot : 2 +++ : ['GO' 'FACADE']",
#  "012EC_Ouvrage : 4 +++ : ['POTEAU RECTANGULAIRE' 'POTEAU PARTICULIER' 'POTEAU CIRCULAIRE' 'MUR']",
#  "013EC_Localisation : 5 +++ : [nan 'INTERIEUR' 'EXTERIEUR' 'COURANT' 'BASSINS PERIPHERIES']",
#  "014EC_Mode Constructif : 4 +++ : ['BANCHE' 'PREFA CHANTIER' 'PREFA USINE' 'CARTON']",
#  "Nom : 36 +++ : ['110x30' '40x30' '60x30' '40x40' '50x40' '50x30' '70x40' '45x40' '15x15'\n '60x40' '25x60' '20x30' '25x30' '20x20' '20x40' '20x60' '500x500'\n '400x400' '800x290' '400x250' '400x800' '900x300' '900x200' '905x200'\n 'Ø 30' 'Ø 30 cm  C35/45' 'Ø 25 cm' '40 x 40' '20 x 20' '25 x 25'\n '25 x 35' '35 x 35' '30 x 30' '30 x 25' '35 x 25' 'Ø 40 cm']",
#  'AI : 38 +++ : [    nan -1.51   -1.61   -2.15   -2.13   -3.74   -1.82   -0.0725 -0.2225\n -1.375  -1.45   -0.815  -0.5625 -0.6575 -0.575  -0.625  -0.55   -0.4375\n -0.45   -0.775  -1.561  -1.616  -1.311  -1.675  -1.5    -1.515  -1.525\n -1.865  -1.59   -1.615  -1.47   -1.82   -1.35   -1.55   -3.69   -1.25\n -1.865  -2.075 ]',
#  'AS : 38 +++ : [   nan 1.51   1.61   2.15   2.13   3.74   1.82   0.0725 0.2225 1.375\n 1.45   0.815  0.5625 0.6575 0.575  0.625  0.55   0.4375 0.45   0.775\n 1.561  1.616  1.311  1.675  1.5    1.515  1.525  1.865  1.59   1.615\n 1.47   1.82   1.35   1.55   3.69   1.25   1.865  2.075 ]',
#  'Hauteur : 38 +++ : [  nan 3.02  3.22  4.3   4.26  7.48  3.64  0.145 0.445 2.75  2.9   1.63\n 1.125 1.315 1.15  1.25  1.1   0.875 0.9   1.55  3.122 3.232 2.622 3.35\n 3.    3.03  3.05  3.73  3.18  3.23  2.94  3.64  2.7   3.1   7.38  2.5\n 3.73  4.15 ]',
#  'Longueur : 71 +++ : [ 2.82        3.57        2.97        2.62        2.47        2.77\n  2.57        2.88        2.28        5.95        5.75        5.7\n  5.5         2.4         2.75        2.35        3.55        2.65\n  2.74        2.2         0.17        2.72        2.95        3.35\n  3.          3.03        3.05        3.73        3.18        3.23\n  2.94        3.64        2.7         3.1         7.38        2.5\n  4.15       10.56430446 10.56430446 14.10761155 13.97637795 24.54068241\n 11.94225722  0.47572178  1.45997375  9.02230971 13.54986877  3.69094488\n  4.31430446  3.77296588  4.10104987  3.60892388  2.87073491  2.95275591\n  5.34776903 10.60367454  8.96325459 10.99081365  9.84251969  9.94094488\n 10.00656168 12.23753281 10.43307087 10.59711286  9.64566929 11.94225722\n  8.85826772 10.17060367 24.21259843  8.20209974 13.61548556]',
#  'Partie inférieure attachée : 3 +++ : [nan  0.  1.]',
#  'Partie supérieure attachée : 3 +++ : [nan  0.  1.]',
#  'Sols en intersection : 3 +++ : [nan  0.  1.]',
#  'Sols coupés (u) : 2 +++ : [nan  0.]',
#  'Sols coupés (Ids) : 1 +++ : [nan]',
#  'Sols coupants (u) : 4 +++ : [nan  1.  0.  2.]',
#  'Sols coupants (Ids) : 18 +++ : [            nan 1788810.        1788433.1790457 1791666.\n 1792082.        1791964.        1792148.        1788628.\n 1788444.1790457 1792889.        1793466.        1795002.\n 1791684.        1788796.1791684 1794926.1794973 1794926.1794957\n  286418.         299923.       ]',
#  'Poutres en intersection : 3 +++ : [ nan 246. 287.]',
#  'Poutres coupés (u) : 8 +++ : [nan  2.  1.  0.  3.  4.  6.  5.]',
#  "Poutres coupés (Ids) : 147 +++ : [nan '1788966,1795639' '1788934' '1788936' '1790429,1790431'\n '1788964,1790885' '1788960,1790889' '1788952,1788966'\n '1790217,1790423,1790425' '1790431,1790433'\n '1788423,1790214,1790425,1790427' '1788952,1791073,1791397'\n '1788954,1791083,1791413' '1791415,1791417' '1791077,1791417,1791419'\n '1788960,1788964,1791411' '1791371,1791405,1791407'\n '1791369,1791407,1791409' '1791367,1791409,1791411'\n '1791073,1791367,1791397,1791399' '1791073,1791369,1791399,1791401'\n '1788934,1791727,1791943' '1791871' '1788930,1791725,1791943'\n '1793850,1793854' '1793836,1793840' '1789000,1791654,1793854'\n '1791650,1791654,1793842,1793848' '1788946,1791642,1791644'\n '1788950,1791644,1791646' '1791871,1791879' '1791879,1795639'\n '1791887,1791913' '1791911,1795645' '1791911,1791913,1793695' '1792960'\n '1793796,1793802,1793856'\n '1793428,1793432,1793672,1793790,1793794,1793856'\n '1793460,1793491,1793668,1793672,1793679,1793683'\n '1793408,1793545,1793802,1793858' '1793545,1793547' '1793547,1793549'\n '1793549,1793862,1793866' '1793561' '1793460,1793597' '1793597'\n '1793613,1793796,1793834' '1793635' '1793639' '1794881,1794907' '1788784'\n '280537' '280537,348367,352301' '280887,281403'\n '282809,282817,348003,348017,350076'\n '282817,282829,282843,347991,348003,348285' '281403,281569,281999'\n '281569,281580,281964' '281964,281965' '281580,281863' '281863,281873'\n '282721,350241,351036,352416' '282356,350257,352416,352431'\n '282721,282731,348224,350231,350241' '282356,282523,350257,350265,350275'\n '282523,282531,346397,350265' '282731,282743,347115,350231,350530'\n '284164,284165,347303,347313' '284095,284164,347303,348140'\n '283775,283931,347337,348152' '283921,347325'\n '284165,284417,347313,347598' '282743,283249,347115,347155,348084'\n '282531,282543,346260,346397' '282543,282551,346492,346504'\n '282551,282561,282662,346504,346518' '283249,347127,347137'\n '282662,347137,347147' '283112,283190,347774,347786' '347038,347786'\n '285425' '283102,283190,347897,347909'\n '283092,283102,347798,347887,347897' '347369,351734' '283640,347981'\n '282829,347981,347991' '351189,351875' '298301' '297088,297285'\n '297285,297381' '297381,297389' '298275,298287,298301,298603'\n '298446,298545' '297409,297516,297524' '297401' '297730,297738'\n '297722,297730' '297722' '297748' '297748,297758' '297758,297770'\n '297770,297868' '297932,297940' '297940,297952' '297952,298700,298708'\n '297738,297960' '297968,297976' '297976,297984' '297984,298638,298700'\n '298545,298638' '314517,314585' '314509,314517' '314433,314509'\n '314838,314935' '314994,315004' '315016,315142' '315016,315180'\n '315152,315160' '315160,315172' '362121,362129' '361176,362242'\n '361176,362232' '362242,362252' '362252,362260' '362260,362270'\n '362270,362282' '362282,362292' '362129,362137' '362137,362145'\n '362145,362153' '362153,362161' '362161,362169' '362113,362121'\n '362103,362113' '362091,362103' '362091' '377308,377318' '377300,377308'\n '377290,377300' '377282,377290' '377274,377282' '377266,377274'\n '377258,377266' '377246,377258' '377224,377236' '377204'\n '376853,377192,377332']",
#  'Poutres coupants (u) : 3 +++ : [nan  0.  1.]',
#  'Poutres coupants (Ids) : 8 +++ : [     nan 1791085. 1793408. 1793428. 1793460. 1793547. 1793549. 1793613.]',
#  "Matériau structurel : 6 +++ : ['ECSA - Béton Poteaux' 'EC - Béton' 'Pin' 'Concrete, Cast-in-Place gray'\n '<Par catégorie>' 'C35/45']",
#  "Marque d'emplacement du poteau : 99 +++ : [nan 'A11(1.38)-1a(-4.29)' 'A13(1.35)-1a' 'A11(1.38)-1a' 'A13(-1.40)-1a'\n 'A11(-1.40)-1a(-4.29)' 'A11(-1.40)-1a' 'A13(-1.40)-1a(-4.29)'\n 'A13(1.35)-1a(-4.29)' 'A10-4a(-0.15)' 'A10(2.88)-3a' 'A11(1.92)-3a'\n 'A9(1.05)-4a(-0.15)' 'A10-4a(-0.10)' 'A9(1.05)-4a(-0.10)' 'A14-0a'\n 'A14(-1.35)-3a' 'A13-3a' 'A10(2.85)-3a' 'A11(1.95)-3a' 'A9-2a'\n 'A13(-2.73)-2a(4.53)' 'A12(1.57)-2a(4.53)' 'A13(2.57)-2a(3.96)'\n 'A10(-1.43)-2a(4.29)' 'A10(-1.43)-2a' 'A13(1.40)-2a' 'A13(1.35)-2a(4.29)'\n 'A13(-0.29)-4a(-0.35)' 'A12(2.76)-4a(-0.35)' 'A14-1a' 'A14-2a'\n 'A13(1.35)-2a(2.09)' 'A13(1.35)-2a(3.09)' 'A13(1.35)-2a(1.19)'\n 'A13(1.35)-1a(-7.68)' 'A13(1.35)-2a(6.09)' 'A13(1.35)-2a(6.81)'\n 'A13(1.35)-2a(5.25)' 'H(10.49)-32(2.47)' 'H-33(2.52)' 'H-34(2.51)'\n 'B(-2.32)-5' 'H(10.49)-36(2.50)' 'H(10.49)-34(2.50)' 'H-32(2.47)'\n 'H-31(2.51)' 'H-29(-3.27)' 'C-12(-1.72)' 'B(-2.32)-4' 'F(-1.07)-5'\n 'F(-1.07)-4' 'H(3.23)-31(-0.49)' 'H(3.23)-28(-0.55)' 'H(15.87)-28(-0.55)'\n 'G(-9.64)-13(0.57)' 'H(3.23)-29(-4.44)' 'G(-9.64)-12(-1.73)'\n 'G(-15.89)-12(-1.73)' 'H(9.62)-29(-4.44)' 'H(9.62)-31(-0.49)'\n 'H(15.87)-31(-0.49)' 'H(2.30)-32(-0.58)' 'H(2.30)-32(0.12)'\n 'H(8.10)-32(-0.58)' 'H(8.03)-36(-0.67)' 'H(8.03)-35(-0.89)'\n 'H(3.59)-35(-0.90)' 'H(3.59)-36(-0.79)' 'H(8.10)-32(0.12)'\n 'H(11.95)-32(0.12)' 'G(-3.25)-10(-2.43)' 'G(-14.15)-10(-2.43)'\n 'G(-8.70)-10(-2.43)' 'H(7.38)-37(2.16)' 'G(-10.77)-8' 'G(-10.79)-7(2.22)'\n 'G(-10.79)-5(2.86)' 'G(-3.25)-8' 'G(-3.25)-7(2.22)' 'G(-3.25)-5(2.86)'\n 'G(-3.25)-4(1.02)' 'G(-10.79)-4(1.02)' 'H(11.90)-36(-0.29)'\n 'H(11.90)-35(0.67)' 'H(11.90)-34(1.68)' 'H(11.90)-33(0.54)'\n 'G(-8.70)-9(2.78)' 'G(-3.26)-9(2.79)' 'H(4.95)-38(-2.75)'\n 'H(-1.86)-38(-1.49)' 'H(-8.80)-38(-2.98)' 'B(0.24)-8' 'H(10.79)-37(2.50)'\n 'H-35(2.49)' 'G(-1.50)-1(2.57)' 'G(-0.24)-1(2.57)' 'G(-0.24)-3(-1.72)'\n 'G(-2.70)-3(-0.80)']",
#  'Décalage supérieur : 40 +++ : [-7.500e-01  0.000e+00 -6.000e-01 -9.500e-01 -1.100e+00 -8.000e-01\n -1.000e+00 -5.000e-01 -7.000e-01 -2.100e-15 -6.700e-01 -7.000e-02\n -2.700e-01 -8.200e-01 -2.300e-01 -3.000e-01 -6.800e-01 -7.300e-01\n -5.500e-01 -1.260e+00 -1.140e+00  5.100e-01  3.200e-15  4.300e-15\n -2.000e-02 -3.900e-01 -1.405e+00 -1.105e+00 -4.700e-01 -2.225e+00\n -2.035e+00 -2.200e+00 -2.095e+00 -1.970e+00 -2.250e+00 -2.345e+00\n -2.320e+00 -2.853e-13 -1.028e+00 -1.528e+00]',
#  'Décalage inférieur : 14 +++ : [ 0.000e+00 -2.000e-16  3.500e-01 -6.000e-01 -7.000e-02 -1.500e-01\n -4.000e-01 -3.000e-01  9.700e-01 -1.300e-01 -1.300e-01 -8.707e-13\n  2.500e+00 -2.850e-13]',
#  'Longueur : 71 +++ : [ 2.82        3.57        2.97        2.62        2.47        2.77\n  2.57        2.88        2.28        5.95        5.75        5.7\n  5.5         2.4         2.75        2.35        3.55        2.65\n  2.74        2.2         0.17        2.72        2.95        3.35\n  3.          3.03        3.05        3.73        3.18        3.23\n  2.94        3.64        2.7         3.1         7.38        2.5\n  4.15       10.56430446 10.56430446 14.10761155 13.97637795 24.54068241\n 11.94225722  0.47572178  1.45997375  9.02230971 13.54986877  3.69094488\n  4.31430446  3.77296588  4.10104987  3.60892388  2.87073491  2.95275591\n  5.34776903 10.60367454  8.96325459 10.99081365  9.84251969  9.94094488\n 10.00656168 12.23753281 10.43307087 10.59711286  9.64566929 11.94225722\n  8.85826772 10.17060367 24.21259843  8.20209974 13.61548556]',
#  'Sols coupés (Ids) : 1 +++ : [nan]',
#  'Sols coupants (Ids) : 18 +++ : [            nan 1788810.        1788433.1790457 1791666.\n 1792082.        1791964.        1792148.        1788628.\n 1788444.1790457 1792889.        1793466.        1795002.\n 1791684.        1788796.1791684 1794926.1794973 1794926.1794957\n  286418.         299923.       ]',
#  "Poutres coupés (Ids) : 147 +++ : [nan '1788966,1795639' '1788934' '1788936' '1790429,1790431'\n '1788964,1790885' '1788960,1790889' '1788952,1788966'\n '1790217,1790423,1790425' '1790431,1790433'\n '1788423,1790214,1790425,1790427' '1788952,1791073,1791397'\n '1788954,1791083,1791413' '1791415,1791417' '1791077,1791417,1791419'\n '1788960,1788964,1791411' '1791371,1791405,1791407'\n '1791369,1791407,1791409' '1791367,1791409,1791411'\n '1791073,1791367,1791397,1791399' '1791073,1791369,1791399,1791401'\n '1788934,1791727,1791943' '1791871' '1788930,1791725,1791943'\n '1793850,1793854' '1793836,1793840' '1789000,1791654,1793854'\n '1791650,1791654,1793842,1793848' '1788946,1791642,1791644'\n '1788950,1791644,1791646' '1791871,1791879' '1791879,1795639'\n '1791887,1791913' '1791911,1795645' '1791911,1791913,1793695' '1792960'\n '1793796,1793802,1793856'\n '1793428,1793432,1793672,1793790,1793794,1793856'\n '1793460,1793491,1793668,1793672,1793679,1793683'\n '1793408,1793545,1793802,1793858' '1793545,1793547' '1793547,1793549'\n '1793549,1793862,1793866' '1793561' '1793460,1793597' '1793597'\n '1793613,1793796,1793834' '1793635' '1793639' '1794881,1794907' '1788784'\n '280537' '280537,348367,352301' '280887,281403'\n '282809,282817,348003,348017,350076'\n '282817,282829,282843,347991,348003,348285' '281403,281569,281999'\n '281569,281580,281964' '281964,281965' '281580,281863' '281863,281873'\n '282721,350241,351036,352416' '282356,350257,352416,352431'\n '282721,282731,348224,350231,350241' '282356,282523,350257,350265,350275'\n '282523,282531,346397,350265' '282731,282743,347115,350231,350530'\n '284164,284165,347303,347313' '284095,284164,347303,348140'\n '283775,283931,347337,348152' '283921,347325'\n '284165,284417,347313,347598' '282743,283249,347115,347155,348084'\n '282531,282543,346260,346397' '282543,282551,346492,346504'\n '282551,282561,282662,346504,346518' '283249,347127,347137'\n '282662,347137,347147' '283112,283190,347774,347786' '347038,347786'\n '285425' '283102,283190,347897,347909'\n '283092,283102,347798,347887,347897' '347369,351734' '283640,347981'\n '282829,347981,347991' '351189,351875' '298301' '297088,297285'\n '297285,297381' '297381,297389' '298275,298287,298301,298603'\n '298446,298545' '297409,297516,297524' '297401' '297730,297738'\n '297722,297730' '297722' '297748' '297748,297758' '297758,297770'\n '297770,297868' '297932,297940' '297940,297952' '297952,298700,298708'\n '297738,297960' '297968,297976' '297976,297984' '297984,298638,298700'\n '298545,298638' '314517,314585' '314509,314517' '314433,314509'\n '314838,314935' '314994,315004' '315016,315142' '315016,315180'\n '315152,315160' '315160,315172' '362121,362129' '361176,362242'\n '361176,362232' '362242,362252' '362252,362260' '362260,362270'\n '362270,362282' '362282,362292' '362129,362137' '362137,362145'\n '362145,362153' '362153,362161' '362161,362169' '362113,362121'\n '362103,362113' '362091,362103' '362091' '377308,377318' '377300,377308'\n '377290,377300' '377282,377290' '377274,377282' '377266,377274'\n '377258,377266' '377246,377258' '377224,377236' '377204'\n '376853,377192,377332']",
#  'Poutres coupants (Ids) : 8 +++ : [     nan 1791085. 1793408. 1793428. 1793460. 1793547. 1793549. 1793613.]']

# %%
percent_missing = dfs_concat[all_features].isnull().sum() * 100 / len(df)
missing_value_df = pd.DataFrame({'column_name': df.columns,
                                 'percent_missing': percent_missing})

# %%
feature_list = missing_value_df.sort_values('percent_missing', ascending=False)['column_name'].to_list()

# %%
selected_feature_list =  [ '013EC_Localisation',
                            'Décalage inférieur',
                            '012EC_Ouvrage',
                            '014EC_Mode Constructif',
                            'Matériau structurel',
                            'Décalage supérieur',
                            'Nom',
                            '011EC_Lot',
                            'Longueur',
                            'Famille et type'
                            ]
dfs_concat[selected_feature_list].sample(2)
# Out:
#     013EC_Localisation  Décalage inférieur         012EC_Ouvrage  \
# 286          INTERIEUR                 0.0  POTEAU RECTANGULAIRE
# 561          EXTERIEUR                 0.0  POTEAU RECTANGULAIRE
#
#     014EC_Mode Constructif           Matériau structurel  Décalage supérieur  \
# 286                 BANCHE                    EC - Béton                -0.3
# 561                 CARTON  Concrete, Cast-in-Place gray                 0.0
#
#          Nom 011EC_Lot   Longueur                      Famille et type
# 286    25x60        GO   2.720000  Poteau béton - Rectangulaire: 25x60
# 561  400x400        GO  12.237533       EIF_STR - Poteau rect: 400x400

# %%
df_clean = dfs_concat[selected_feature_list].dropna(axis=0, how='any')
df_clean.shape
# Out:
# (519, 10)

# %%
#ignoring '011EC_Lot' for now / all GO
X = df_clean.drop(columns = ['012EC_Ouvrage','013EC_Localisation','014EC_Mode Constructif','011EC_Lot'])
y = df_clean[['012EC_Ouvrage','013EC_Localisation','014EC_Mode Constructif']]
y.shape, X.shape
# Out:
# ((519, 3), (519, 6))

# %%
y
# Out:
#             012EC_Ouvrage 013EC_Localisation 014EC_Mode Constructif
# 22   POTEAU RECTANGULAIRE          INTERIEUR                 BANCHE
# 67   POTEAU RECTANGULAIRE          EXTERIEUR         PREFA CHANTIER
# 68   POTEAU RECTANGULAIRE          EXTERIEUR         PREFA CHANTIER
# 69   POTEAU RECTANGULAIRE          EXTERIEUR         PREFA CHANTIER
# 70   POTEAU RECTANGULAIRE          EXTERIEUR         PREFA CHANTIER
# ..                    ...                ...                    ...
# 580     POTEAU CIRCULAIRE          EXTERIEUR                 BANCHE
# 581     POTEAU CIRCULAIRE          EXTERIEUR                 BANCHE
# 582     POTEAU CIRCULAIRE          EXTERIEUR                 BANCHE
# 583     POTEAU CIRCULAIRE          EXTERIEUR                 BANCHE
# 584  POTEAU RECTANGULAIRE          EXTERIEUR                 CARTON
#
# [519 rows x 3 columns]

# %%
from sklearn.preprocessing import OneHotEncoder

for feat in X.columns:
    print(f'the uniques for {feat}: {len(X[feat].unique())}')
# Out:
# the uniques for Décalage inférieur: 13
# the uniques for Matériau structurel: 6
# the uniques for Décalage supérieur: 36
# the uniques for Nom: 29
# the uniques for Longueur: 62
# the uniques for Famille et type: 30

# %%
ohe = OneHotEncoder(sparse_output=False)
ohe.fit(X[['Matériau structurel']])
# Out:
# OneHotEncoder(sparse_output=False)

# %%
ohe.categories_
ohe.get_feature_names_out()
# Out:
# array(['Matériau structurel_<Par catégorie>',
#        'Matériau structurel_C35/45',
#        'Matériau structurel_Concrete, Cast-in-Place gray',
#        'Matériau structurel_EC - Béton',
#        'Matériau structurel_ECSA - Béton Poteaux',
#        'Matériau structurel_Pin'], dtype=object)

# %%
feats = ['Matériau structurel','Famille et type']
for feat in feats:
    print(f'Transforming {feat}: {len(X[feat].unique())} values')
    ohe = OneHotEncoder(sparse_output=False)
    ohe.fit(X[[feat]])
    X[ohe.get_feature_names_out()] = ohe.transform(X[[feat]])
    X.drop(columns=[feat], inplace=True)
# Out:
# Transforming Matériau structurel: 6 values
# Transforming Famille et type: 30 values

# %%
X.shape
# Out:
# (519, 40)

# %%
y['012EC_Ouvrage'].unique()
# Out:
# array(['POTEAU RECTANGULAIRE', 'POTEAU PARTICULIER', 'POTEAU CIRCULAIRE',
#        'MUR'], dtype=object)

# %%
labeler2 = {'POTEAU RECTANGULAIRE':0,
           'POTEAU PARTICULIER':1,
           'POTEAU CIRCULAIRE':2,
           'MUR':3,
}
y['ouvrage'] = y['012EC_Ouvrage'].apply(lambda x: labeler2[x])
# Out:
# /tmp/ipykernel_16994/1705354856.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y['ouvrage'] = y['012EC_Ouvrage'].apply(lambda x: labeler2[x])

# %%
y['013EC_Localisation'].unique()
# Out:
# array(['INTERIEUR', 'EXTERIEUR', 'COURANT', 'BASSINS PERIPHERIES'],
#       dtype=object)

# %%
labeler2 = {'INTERIEUR':0,
           'EXTERIEUR':1,
           'COURANT':2,
           'BASSINS PERIPHERIES':3,
}
y['local'] = y['013EC_Localisation'].apply(lambda x: labeler2[x])
# Out:
# /tmp/ipykernel_16994/2827905674.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y['local'] = y['013EC_Localisation'].apply(lambda x: labeler2[x])

# %%
y['014EC_Mode Constructif'].unique()
# Out:
# array(['BANCHE', 'PREFA CHANTIER', 'PREFA USINE', 'CARTON'], dtype=object)

# %%
y['014EC_Mode Constructif'].unique()
labeler1 = {'BANCHE':0,
           'PREFA CHANTIER':1,
           'PREFA USINE':2,
           'CARTON':3,
       }
y['const'] = y['014EC_Mode Constructif'].apply(lambda x: labeler1[x])
# Out:
# /tmp/ipykernel_16994/1203657966.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y['const'] = y['014EC_Mode Constructif'].apply(lambda x: labeler1[x])

# %%
y.sample(1)
# Out:
#             012EC_Ouvrage 013EC_Localisation 014EC_Mode Constructif  local  \
# 515  POTEAU RECTANGULAIRE          INTERIEUR                 CARTON      0
#
#      Ouvrage  construc
# 515        0         3

# %%
from sklearn.dummy import DummyClassifier


dummy_clf_local = DummyClassifier(strategy="stratified")
dummy_clf_local.fit(X, y.local)
# Out:
# DummyClassifier(strategy='stratified')

# %%
set(dummy_clf_local.predict(X))
# Out:
# {0, 1, 2, 3}

# %%
dummy_clf_local.score(X, y.local)
# Out:
# 0.49710982658959535

# %%
dummy_clf_construc = DummyClassifier(strategy="stratified")
dummy_clf_construc.fit(X, y.const)
# Out:
# DummyClassifier(strategy='stratified')

# %%
set(dummy_clf_construc.predict(X))
# Out:
# {0, 1, 2, 3}

# %%
dummy_clf_construc.score(X, y.const)
# Out:
# 0.35645472061657035

# %%
dummy_clf_ouvrage = DummyClassifier(strategy="stratified")
dummy_clf_ouvrage.fit(X, y.ouvrage)
# Out:
# DummyClassifier(strategy='stratified')

# %%
y_pred = dummy_clf_ouvrage.predict(X)

# %%
dummy_clf_ouvrage.score(y_pred, y.const)
# Out:
# 0.35260115606936415
