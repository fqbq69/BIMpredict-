# %%
import joblib
import pandas as pd
import unicodedata
import re
import pickle
import os
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.multioutput import MultiOutputClassifier
from sklearn.metrics import accuracy_score, mean_squared_error

# %%
pipeline_path = "/Users/fabiancordenod/code/fqbq69/BIMpredict-/notebooks/fabian/randomforestpoteauxpipeline.pkl"
pipeline = joblib.load(pipeline_path)

# %%
# Charger le CSV
csv_path = "/Users/fabiancordenod/code/fqbq69/BIMpredict-/raw_data/datatest/test/poteaux1.csv"
df_test = pd.read_csv(csv_path, delimiter=';')

# Nettoyer les noms de colonnes comme à l'entraînement
def clean_col(col):
    col = ''.join(c for c in unicodedata.normalize('NFD', col) if unicodedata.category(c) != 'Mn')
    col = col.lower()
    col = re.sub(r"[ \-\(\)]", "_", col)
    col = re.sub(r"[^a-z0-9_]", "", col)
    col = re.sub(r"_+", "_", col)
    col = col.strip("_")
    return col

df_test.columns = [clean_col(c) for c in df_test.columns]

# %%
df_test
# Out:
#          id  011ec_lot  012ec_ouvrage  013ec_localisation  \
# 0    636523        NaN            NaN                 NaN
# 1    636547        NaN            NaN                 NaN
# 2    636549        NaN            NaN                 NaN
# 3    636551        NaN            NaN                 NaN
# 4    636553        NaN            NaN                 NaN
# 5    636568        NaN            NaN                 NaN
# 6    636570        NaN            NaN                 NaN
# 7    636572        NaN            NaN                 NaN
# 8    636575        NaN            NaN                 NaN
# 9    636577        NaN            NaN                 NaN
# 10   636579        NaN            NaN                 NaN
# 11   636581        NaN            NaN                 NaN
# 12   636583        NaN            NaN                 NaN
# 13   636585        NaN            NaN                 NaN
# 14   636587        NaN            NaN                 NaN
# 15   636627        NaN            NaN                 NaN
# 16   636706        NaN            NaN                 NaN
# 17   636718        NaN            NaN                 NaN
# 18   636720        NaN            NaN                 NaN
# 19   636722        NaN            NaN                 NaN
# 20   636724        NaN            NaN                 NaN
# 21   636726        NaN            NaN                 NaN
# 22   636728        NaN            NaN                 NaN
# 23   639691        NaN            NaN                 NaN
# 24   639694        NaN            NaN                 NaN
# 25   639700        NaN            NaN                 NaN
# 26   639703        NaN            NaN                 NaN
# 27   639705        NaN            NaN                 NaN
# 28   639709        NaN            NaN                 NaN
# 29   639711        NaN            NaN                 NaN
# 30   639750        NaN            NaN                 NaN
# 31   639753        NaN            NaN                 NaN
# 32   712572        NaN            NaN                 NaN
# 33   712862        NaN            NaN                 NaN
# 34   713021        NaN            NaN                 NaN
# 35   717124        NaN            NaN                 NaN
# 36   717347        NaN            NaN                 NaN
# 37   722560        NaN            NaN                 NaN
# 38   724194        NaN            NaN                 NaN
# 39   726988        NaN            NaN                 NaN
# 40   727061        NaN            NaN                 NaN
# 41   980943        NaN            NaN                 NaN
# 42  1004610        NaN            NaN                 NaN
# 43  1005067        NaN            NaN                 NaN
# 44  1005119        NaN            NaN                 NaN
# 45  1005135        NaN            NaN                 NaN
# 46  1005151        NaN            NaN                 NaN
# 47  1005577        NaN            NaN                 NaN
# 48  1005714        NaN            NaN                 NaN
#
#     014ec_mode_constructif     nom                 ai                as  \
# 0                      NaN  25x110  -1,08499999999999  1,08499999999999
# 1                      NaN  25x110              -1,44              1,44
# 2                      NaN  25x110              -1,44              1,44
# 3                      NaN  25x110              -1,44              1,44
# 4                      NaN  25x110              -1,44              1,44
# 5                      NaN  25x110  -1,43999999999775  1,43999999999775
# 6                      NaN  25x110  -1,43999999999775  1,43999999999775
# 7                      NaN  25x110              -1,44              1,44
# 8                      NaN  25x110  -1,23500000000062  1,23500000000062
# 9                      NaN  25x110  -1,23500000000062  1,23500000000062
# 10                     NaN  25x110  -1,23500000000062  1,23500000000062
# 11                     NaN  25x110  -1,52999999999999  1,52999999999999
# 12                     NaN  25x110  -1,23500000000062  1,23500000000062
# 13                     NaN  25x110  -1,23500000000062  1,23500000000062
# 14                     NaN  25x110  -1,23500000000062  1,23500000000062
# 15                     NaN  25x110              -1,44              1,44
# 16                     NaN  25x110  -1,23500000000062  1,23500000000062
# 17                     NaN  25x110  -1,52999999999999  1,52999999999999
# 18                     NaN  25x110  -1,23500000000062  1,23500000000062
# 19                     NaN  25x110  -1,23500000000062  1,23500000000062
# 20                     NaN  25x110  -1,23500000000062  1,23500000000062
# 21                     NaN  25x110  -1,08499999999999  1,08499999999999
# 22                     NaN  25x110              -1,44              1,44
# 23                     NaN  25x110  -1,47000000000034  1,47000000000034
# 24                     NaN  25x110  -1,52999999999999  1,52999999999999
# 25                     NaN  25x110  -1,05999999999984  1,05999999999984
# 26                     NaN  25x110  -1,23500000000062  1,23500000000062
# 27                     NaN  25x110  -1,23500000000062  1,23500000000062
# 28                     NaN  25x110  -1,29499999999984  1,29499999999984
# 29                     NaN  25x110  -1,29499999999984  1,29499999999984
# 30                     NaN  25x110  -1,05999999999984  1,05999999999984
# 31                     NaN  25x110  -1,08499999999999  1,08499999999999
# 32                     NaN   20X26             -1,275             1,275
# 33                     NaN   20x50             -1,275             1,275
# 34                     NaN   20X40             -1,275             1,275
# 35                     NaN   20X26             -1,275             1,275
# 36                     NaN   20X40             -1,275             1,275
# 37                     NaN   20X26  -1,27499999999999  1,27499999999999
# 38                     NaN   20x50  -1,27499999999999  1,27499999999999
# 39                     NaN   20X26             -1,275             1,275
# 40                     NaN   20x50              -1,26              1,26
# 41                     NaN   20x50             -1,275             1,275
# 42                     NaN   16X16  -1,27499999999999  1,27499999999999
# 43                     NaN   16X16              -1,38              1,38
# 44                     NaN   16X16             -1,275             1,275
# 45                     NaN   16X16             -1,275             1,275
# 46                     NaN   16X16  -1,27500000000001  1,27500000000001
# 47                     NaN   16X16  -1,27499999999999  1,27499999999999
# 48                     NaN   16X16              -1,28              1,28
#
#              hauteur          longueur  ...  forme_de_coupe  titre_omniclass  \
# 0   2,16999999999999  7,11942257217746  ...               0              NaN
# 1   2,87999999999999  9,44881889763776  ...               0              NaN
# 2   2,87999999999999  9,64566929134084  ...               0              NaN
# 3   2,87999999999999  9,64566929134084  ...               0              NaN
# 4   2,87999999999999  9,64566929134084  ...               0              NaN
# 5   2,87999999999551  9,64566929134084  ...               0              NaN
# 6   2,87999999999551  9,64566929134084  ...               0              NaN
# 7   2,87999999999999  9,64566929134084  ...               0              NaN
# 8   2,47000000000123  8,10367454068645  ...               0              NaN
# 9   2,47000000000123  8,10367454068645  ...               0              NaN
# 10  2,47000000000123  8,10367454068645  ...               0              NaN
# 11  3,05999999999998  10,0393700787401  ...               0              NaN
# 12  2,47000000000123  8,10367454068645  ...               0              NaN
# 13  2,47000000000123  8,10367454068645  ...               0              NaN
# 14  2,47000000000123  8,10367454068645  ...               0              NaN
# 15  2,87999999999999  9,64566929134084  ...               0              NaN
# 16  2,47000000000123  8,10367454068645  ...               0              NaN
# 17  3,05999999999998  10,0393700787401  ...               0              NaN
# 18  2,47000000000123  8,10367454068645  ...               0              NaN
# 19  2,47000000000123  8,10367454068645  ...               0              NaN
# 20  2,47000000000123  8,10367454068645  ...               0              NaN
# 21  2,16999999999999  7,11942257217748  ...               0              NaN
# 22  2,87999999999999  9,64566929134084  ...               0              NaN
# 23  2,94000000000069  9,64566929134084  ...               0              NaN
# 24  3,05999999999998  10,0393700787401  ...               0              NaN
# 25  2,11999999999969   6,9553805774268  ...               0              NaN
# 26  2,47000000000123  8,10367454068645  ...               0              NaN
# 27  2,47000000000123  8,10367454068645  ...               0              NaN
# 28  2,58999999999969  8,49737532808297  ...               0              NaN
# 29  2,58999999999969  8,49737532808297  ...               0              NaN
# 30  2,11999999999969   6,9553805774268  ...               0              NaN
# 31  2,16999999999999  7,11942257217746  ...               0              NaN
# 32              2,55  8,36614173228346  ...               0              NaN
# 33              2,55  8,36614173228346  ...               0              NaN
# 34              2,55  8,36614173228346  ...               0              NaN
# 35              2,55  8,36614173228346  ...               0              NaN
# 36              2,55  8,36614173228346  ...               0              NaN
# 37  2,54999999999999  8,36614173228342  ...               0              NaN
# 38  2,54999999999999  8,36614173228342  ...               0              NaN
# 39              2,55  8,75984251968501  ...               0              NaN
# 40              2,52  8,26771653543307  ...               0              NaN
# 41              2,55  8,36614173228346  ...               0              NaN
# 42  2,54999999999999  8,36614173228342  ...               0              NaN
# 43  2,75999999999999  9,05511811023619  ...               0              NaN
# 44              2,55  8,36614173228346  ...               0              NaN
# 45              2,55  8,36614173228346  ...               0              NaN
# 46  2,55000000000002  8,36614173228352  ...               0              NaN
# 47  2,54999999999999  8,36614173228342  ...               0              NaN
# 48  2,55999999999999  8,39895013123357  ...               0              NaN
#
#     numero_omniclass  description_de_lassemblage  code_dassemblage  \
# 0                NaN                         NaN               NaN
# 1                NaN                         NaN               NaN
# 2                NaN                         NaN               NaN
# 3                NaN                         NaN               NaN
# 4                NaN                         NaN               NaN
# 5                NaN                         NaN               NaN
# 6                NaN                         NaN               NaN
# 7                NaN                         NaN               NaN
# 8                NaN                         NaN               NaN
# 9                NaN                         NaN               NaN
# 10               NaN                         NaN               NaN
# 11               NaN                         NaN               NaN
# 12               NaN                         NaN               NaN
# 13               NaN                         NaN               NaN
# 14               NaN                         NaN               NaN
# 15               NaN                         NaN               NaN
# 16               NaN                         NaN               NaN
# 17               NaN                         NaN               NaN
# 18               NaN                         NaN               NaN
# 19               NaN                         NaN               NaN
# 20               NaN                         NaN               NaN
# 21               NaN                         NaN               NaN
# 22               NaN                         NaN               NaN
# 23               NaN                         NaN               NaN
# 24               NaN                         NaN               NaN
# 25               NaN                         NaN               NaN
# 26               NaN                         NaN               NaN
# 27               NaN                         NaN               NaN
# 28               NaN                         NaN               NaN
# 29               NaN                         NaN               NaN
# 30               NaN                         NaN               NaN
# 31               NaN                         NaN               NaN
# 32               NaN                         NaN               NaN
# 33               NaN                         NaN               NaN
# 34               NaN                         NaN               NaN
# 35               NaN                         NaN               NaN
# 36               NaN                         NaN               NaN
# 37               NaN                         NaN               NaN
# 38               NaN                         NaN               NaN
# 39               NaN                         NaN               NaN
# 40               NaN                         NaN               NaN
# 41               NaN                         NaN               NaN
# 42               NaN                         NaN               NaN
# 43               NaN                         NaN               NaN
# 44               NaN                         NaN               NaN
# 45               NaN                         NaN               NaN
# 46               NaN                         NaN               NaN
# 47               NaN                         NaN               NaN
# 48               NaN                         NaN               NaN
#
#     marque_de_type cout  t_dimension     h     b
# 0              NaN    0          NaN   1,1  0,25
# 1              NaN    0          NaN   1,1  0,25
# 2              NaN    0          NaN   1,1  0,25
# 3              NaN    0          NaN   1,1  0,25
# 4              NaN    0          NaN   1,1  0,25
# 5              NaN    0          NaN   1,1  0,25
# 6              NaN    0          NaN   1,1  0,25
# 7              NaN    0          NaN   1,1  0,25
# 8              NaN    0          NaN   1,1  0,25
# 9              NaN    0          NaN   1,1  0,25
# 10             NaN    0          NaN   1,1  0,25
# 11             NaN    0          NaN   1,1  0,25
# 12             NaN    0          NaN   1,1  0,25
# 13             NaN    0          NaN   1,1  0,25
# 14             NaN    0          NaN   1,1  0,25
# 15             NaN    0          NaN   1,1  0,25
# 16             NaN    0          NaN   1,1  0,25
# 17             NaN    0          NaN   1,1  0,25
# 18             NaN    0          NaN   1,1  0,25
# 19             NaN    0          NaN   1,1  0,25
# 20             NaN    0          NaN   1,1  0,25
# 21             NaN    0          NaN   1,1  0,25
# 22             NaN    0          NaN   1,1  0,25
# 23             NaN    0          NaN   1,1  0,25
# 24             NaN    0          NaN   1,1  0,25
# 25             NaN    0          NaN   1,1  0,25
# 26             NaN    0          NaN   1,1  0,25
# 27             NaN    0          NaN   1,1  0,25
# 28             NaN    0          NaN   1,1  0,25
# 29             NaN    0          NaN   1,1  0,25
# 30             NaN    0          NaN   1,1  0,25
# 31             NaN    0          NaN   1,1  0,25
# 32             NaN    0          NaN  0,26   0,2
# 33             NaN    0          NaN   0,5   0,2
# 34             NaN    0          NaN   0,4   0,2
# 35             NaN    0          NaN  0,26   0,2
# 36             NaN    0          NaN   0,4   0,2
# 37             NaN    0          NaN  0,26   0,2
# 38             NaN    0          NaN   0,5   0,2
# 39             NaN    0          NaN  0,26   0,2
# 40             NaN    0          NaN   0,5   0,2
# 41             NaN    0          NaN   0,5   0,2
# 42             NaN    0          NaN  0,16  0,16
# 43             NaN    0          NaN  0,16  0,16
# 44             NaN    0          NaN  0,16  0,16
# 45             NaN    0          NaN  0,16  0,16
# 46             NaN    0          NaN  0,16  0,16
# 47             NaN    0          NaN  0,16  0,16
# 48             NaN    0          NaN  0,16  0,16
#
# [49 rows x 86 columns]

# %%
# Les targets à prédire (après nettoyage)
targets = [
    "011ec_lot",
    "012ec_ouvrage",
    "013ec_localisation",
    "014ec_mode_constructif"
]

# Colonnes explicatives attendues par le pipeline
features = pipeline.named_steps['preprocessor'].feature_names_in_

# S'assurer que toutes les colonnes sont présentes
for col in features:
    if col not in df_test.columns:
        df_test[col] = np.nan
X_test = df_test[features].copy()

# %%
y_pred = pipeline.predict(X_test)

# %%
y_pred
# Out:
# array([['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
#        ['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
#        ['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
#        ['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
#        ['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
#        ['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
#        ['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
#        ['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
#        ['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
#        ['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
#        ['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
#        ['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
#        ['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
#        ['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
#        ['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
#        ['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
#        ['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
#        ['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
#        ['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
#        ['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
#        ['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
#        ['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
#        ['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
#        ['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
#        ['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
#        ['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
#        ['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
#        ['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
#        ['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
#        ['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
#        ['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
#        ['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
#        ['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
#        ['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
#        ['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
#        ['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
#        ['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
#        ['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
#        ['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
#        ['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
#        ['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
#        ['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
#        ['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
#        ['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
#        ['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
#        ['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
#        ['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
#        ['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE'],
#        ['GO', 'POTEAU RECTANGULAIRE', 'INTERIEUR', 'BANCHE']],
#       dtype=object)

# %%
# Les targets à prédire (après nettoyage)
targets = [
    "011ec_lot",
    "012ec_ouvrage",
    "013ec_localisation",
    "014ec_mode_constructif"
]

# Mettre les prédictions dans un DataFrame
df_pred = pd.DataFrame(y_pred, columns=targets)

# Afficher les premières lignes
print(df_pred.head(200))
# Out:
#    011ec_lot         012ec_ouvrage 013ec_localisation 014ec_mode_constructif
# 0         GO  POTEAU RECTANGULAIRE          INTERIEUR                 BANCHE
# 1         GO  POTEAU RECTANGULAIRE          INTERIEUR                 BANCHE
# 2         GO  POTEAU RECTANGULAIRE          INTERIEUR                 BANCHE
# 3         GO  POTEAU RECTANGULAIRE          INTERIEUR                 BANCHE
# 4         GO  POTEAU RECTANGULAIRE          INTERIEUR                 BANCHE
# 5         GO  POTEAU RECTANGULAIRE          INTERIEUR                 BANCHE
# 6         GO  POTEAU RECTANGULAIRE          INTERIEUR                 BANCHE
# 7         GO  POTEAU RECTANGULAIRE          INTERIEUR                 BANCHE
# 8         GO  POTEAU RECTANGULAIRE          INTERIEUR                 BANCHE
# 9         GO  POTEAU RECTANGULAIRE          INTERIEUR                 BANCHE
# 10        GO  POTEAU RECTANGULAIRE          INTERIEUR                 BANCHE
# 11        GO  POTEAU RECTANGULAIRE          INTERIEUR                 BANCHE
# 12        GO  POTEAU RECTANGULAIRE          INTERIEUR                 BANCHE
# 13        GO  POTEAU RECTANGULAIRE          INTERIEUR                 BANCHE
# 14        GO  POTEAU RECTANGULAIRE          INTERIEUR                 BANCHE
# 15        GO  POTEAU RECTANGULAIRE          INTERIEUR                 BANCHE
# 16        GO  POTEAU RECTANGULAIRE          INTERIEUR                 BANCHE
# 17        GO  POTEAU RECTANGULAIRE          INTERIEUR                 BANCHE
# 18        GO  POTEAU RECTANGULAIRE          INTERIEUR                 BANCHE
# 19        GO  POTEAU RECTANGULAIRE          INTERIEUR                 BANCHE
# 20        GO  POTEAU RECTANGULAIRE          INTERIEUR                 BANCHE
# 21        GO  POTEAU RECTANGULAIRE          INTERIEUR                 BANCHE
# 22        GO  POTEAU RECTANGULAIRE          INTERIEUR                 BANCHE
# 23        GO  POTEAU RECTANGULAIRE          INTERIEUR                 BANCHE
# 24        GO  POTEAU RECTANGULAIRE          INTERIEUR                 BANCHE
# 25        GO  POTEAU RECTANGULAIRE          INTERIEUR                 BANCHE
# 26        GO  POTEAU RECTANGULAIRE          INTERIEUR                 BANCHE
# 27        GO  POTEAU RECTANGULAIRE          INTERIEUR                 BANCHE
# 28        GO  POTEAU RECTANGULAIRE          INTERIEUR                 BANCHE
# 29        GO  POTEAU RECTANGULAIRE          INTERIEUR                 BANCHE
# 30        GO  POTEAU RECTANGULAIRE          INTERIEUR                 BANCHE
# 31        GO  POTEAU RECTANGULAIRE          INTERIEUR                 BANCHE
# 32        GO  POTEAU RECTANGULAIRE          INTERIEUR                 BANCHE
# 33        GO  POTEAU RECTANGULAIRE          INTERIEUR                 BANCHE
# 34        GO  POTEAU RECTANGULAIRE          INTERIEUR                 BANCHE
# 35        GO  POTEAU RECTANGULAIRE          INTERIEUR                 BANCHE
# 36        GO  POTEAU RECTANGULAIRE          INTERIEUR                 BANCHE
# 37        GO  POTEAU RECTANGULAIRE          INTERIEUR                 BANCHE
# 38        GO  POTEAU RECTANGULAIRE          INTERIEUR                 BANCHE
# 39        GO  POTEAU RECTANGULAIRE          INTERIEUR                 BANCHE
# 40        GO  POTEAU RECTANGULAIRE          INTERIEUR                 BANCHE
# 41        GO  POTEAU RECTANGULAIRE          INTERIEUR                 BANCHE
# 42        GO  POTEAU RECTANGULAIRE          INTERIEUR                 BANCHE
# 43        GO  POTEAU RECTANGULAIRE          INTERIEUR                 BANCHE
# 44        GO  POTEAU RECTANGULAIRE          INTERIEUR                 BANCHE
# 45        GO  POTEAU RECTANGULAIRE          INTERIEUR                 BANCHE
# 46        GO  POTEAU RECTANGULAIRE          INTERIEUR                 BANCHE
# 47        GO  POTEAU RECTANGULAIRE          INTERIEUR                 BANCHE
# 48        GO  POTEAU RECTANGULAIRE          INTERIEUR                 BANCHE

# %%
df_pred.to_csv("resultats_predictionspoteaux1.csv", index=False)
